# %%
import os
import sys
import random
os.environ["KERAS_BACKEND"] = "tensorflow"

import glob
try:
    if not ("CUDA_VISIBLE_DEVICES" in os.environ):
        os.environ['CUDA_VISIBLE_DEVICES']='0'
        print("importing setGPU")
        import setGPU
except:
    print("Could not import setGPU, please make sure you configure CUDA_VISIBLE_DEVICES manually")
    pass

import pickle
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, accuracy_score
import pandas
import time
from tqdm import tqdm
import itertools
import io
import sklearn
import sklearn.cluster
import tensorflow as tf
from numpy.lib.recfunctions import append_fields

import scipy
import scipy.special

from mpnn import MessagePassing, ReadoutGraph, Aggregation
# Out:
# importing setGPU
# Could not import setGPU, please make sure you configure CUDA_VISIBLE_DEVICES manually

# %%
import tensorflow as tf
import json, os
import numpy as np

# Tested with TensorFlow 2.1.0
print('version={}, CUDA={}, GPU={}, TPU={}'.format(
    tf.__version__, tf.test.is_built_with_cuda(),
    # GPU attached?
    len(tf.config.list_physical_devices('GPU')) > 0,
    # TPU accessible? (only works on Colab)
    'COLAB_TPU_ADDR' in os.environ))
# Out:
# version=2.1.0, CUDA=True, GPU=True, TPU=False

# %%
try:
    num_gpus = len(os.environ["CUDA_VISIBLE_DEVICES"].split(","))
    print("num_gpus=", num_gpus)
    if num_gpus > 1:
        strategy = tf.distribute.MirroredStrategy()
    else:
        strategy = tf.distribute.OneDeviceStrategy("gpu:0")
except Exception as e:
    print(e)
    print("fallback to CPU")
    strategy = tf.distribute.OneDeviceStrategy("cpu")
# Out:
# num_gpus= 1

# %%
#tf.config.experimental_run_functions_eagerly(True)

# %%
def dist(A,B):
    na = tf.reduce_sum(tf.square(A), -1)
    nb = tf.reduce_sum(tf.square(B), -1)
 
    na = tf.reshape(na, [tf.shape(na)[0], -1, 1])
    nb = tf.reshape(nb, [tf.shape(na)[0], 1, -1])
    Dsq = tf.clip_by_value(na - 2*tf.linalg.matmul(A, B, transpose_a=False, transpose_b=True) + nb, 1e-12, 1e12)
    D = tf.sqrt(Dsq)
    return D

# %%
#Given a list of [Nbatch, Nelem, Nfeat] input nodes, computes the dense [Nbatch, Nelem, Nelem] adjacency matrices
class Distance(tf.keras.layers.Layer):

    def __init__(self, dist_shape, *args, **kwargs):
        super(Distance, self).__init__(*args, **kwargs)

    def call(self, inputs1, inputs2):
        #compute the pairwise distance matrix between the vectors defined by the first two components of the input array
        #inputs1, inputs2: [Nbatch, Nelem, distance_dim] embedded coordinates used for element-to-element distance calculation
        D = dist(inputs1, inputs2)
      
        #adjacency between two elements should be high if the distance is small.
        #this is equivalent to radial basis functions. 
        #self-loops adj_{i,i}=1 are included, as D_{i,i}=0 by construction
        adj = tf.math.exp(-1.0*D)

        #optionally set the adjacency matrix to 0 for low values in order to make the matrix sparse.
        #need to test if this improves the result.
        #adj = tf.keras.activations.relu(adj, threshold=0.01)

        return adj

# %%
class InputEncoding(tf.keras.layers.Layer):
    def __init__(self, num_input_classes):
        super(InputEncoding, self).__init__()
        self.num_input_classes = num_input_classes
        
    def call(self, X):
        #X: [Nbatch, Nelem, Nfeat] array of all the input detector element feature data

        #X[:, :, 0] - categorical index of the element type
        Xid = tf.one_hot(tf.cast(X[:, :, 0], tf.int32), self.num_input_classes)

        #X[:, :, 1:] - all the other non-categorical features
        Xprop = X[:, :, 1:]
        return tf.concat([Xid, Xprop], axis=-1)

# %%
## Graph Highway network
# https://arxiv.org/pdf/2004.04635.pdf
#https://github.com/gcucurull/jax-ghnet/blob/master/models.py 
class GHConv(tf.keras.layers.Layer):
    def __init__(self, k, *args, **kwargs):
        self.activation = kwargs.pop("activation")
        self.hidden_dim = args[0]
        self.k = k

        super(GHConv, self).__init__(*args, **kwargs)

        self.W_t = self.add_weight(shape=(self.hidden_dim, self.hidden_dim), name="w_t", initializer="random_normal")
        self.b_t = self.add_weight(shape=(self.hidden_dim, ), name="b_t", initializer="zeros")
        self.W_h = self.add_weight(shape=(self.hidden_dim, self.hidden_dim), name="w_h", initializer="random_normal")
        self.theta = self.add_weight(shape=(self.hidden_dim, self.hidden_dim), name="theta", initializer="random_normal")
 
    def call(self, x, adj):
        #compute the normalization of the adjacency matrix
        in_degrees = tf.reduce_sum(adj, axis=-1)
        #add epsilon to prevent numerical issues from 1/sqrt(x)
        norm = tf.expand_dims(tf.pow(in_degrees + 1e-6, -0.5), -1)
        norm_k = tf.pow(norm, self.k)
        adj_k = tf.pow(adj, self.k)

        f_hom = tf.linalg.matmul(x, self.theta)
        f_hom = tf.linalg.matmul(adj_k, f_hom*norm_k)*norm_k

        f_het = tf.linalg.matmul(x, self.W_h)
        gate = tf.nn.sigmoid(tf.linalg.matmul(x, self.W_t) + self.b_t)
        #tf.print(tf.reduce_mean(f_hom), tf.reduce_mean(f_het), tf.reduce_mean(gate))

        out = gate*f_hom + (1-gate)*f_het
        return out

## Simple Graph Conv layer
class SGConv(tf.keras.layers.Dense):
    def __init__(self, k, *args, **kwargs):
        super(SGConv, self).__init__(*args, **kwargs)
        self.k = k
    
    def call(self, inputs, adj):
        W = self.weights[0]
        b = self.weights[1]

        #compute the normalization of the adjacency matrix
        in_degrees = tf.reduce_sum(adj, axis=-1)
        #add epsilon to prevent numerical issues from 1/sqrt(x)
        norm = tf.expand_dims(tf.pow(in_degrees + 1e-6, -0.5), -1)
        norm_k = tf.pow(norm, self.k)

        support = (tf.linalg.matmul(inputs, W))
     
        #k-th power of the normalized adjacency matrix is nearly equivalent to k consecutive GCN layers
        adj_k = tf.pow(adj, self.k)
        out = tf.linalg.matmul(adj_k, support*norm_k)*norm_k

        return self.activation(out + b)

# %%
#Simple message passing based on a matrix multiplication
class DNNSuperCluster(tf.keras.Model):
    
    def __init__(self, activation=tf.nn.selu, nclass_labels=2, hidden_dim=256, distance_dim=256, num_conv=4, convlayer="ghconv", dropout=0.1):
        super(DNNSuperCluster, self).__init__()
        self.activation = activation
        self.nclass_labels = nclass_labels

        #self.enc = InputEncoding(3)
        
        # layers for distance coordinate extraction
        self.layer_distcoords1 = tf.keras.layers.Dense(hidden_dim, activation=activation, name="distcoords1")
        self.layer_distcoords2 = tf.keras.layers.Dense(hidden_dim, activation=activation, name="distcoords2")
        #self.layer_distcoords3 = tf.keras.layers.Dense(hidden_dim, activation=activation, name="distcoords3")
        self.layer_distcoords = tf.keras.layers.Dense(distance_dim, activation="linear", name="distcoords")

        # layers for feature extraction 
        self.layer_input1 = tf.keras.layers.Dense(hidden_dim, activation=activation, name="input1")
        self.layer_input1_do = tf.keras.layers.Dropout(dropout)
        self.layer_input2 = tf.keras.layers.Dense(hidden_dim, activation=activation, name="input2")
        self.layer_input2_do = tf.keras.layers.Dropout(dropout)
        self.layer_input3 = tf.keras.layers.Dense(2*hidden_dim, activation=activation, name="input3")
        self.layer_input3_do = tf.keras.layers.Dropout(dropout)
        
        self.layer_dist = Distance(distance_dim, name="distance")

        # Graph convolutions
        if convlayer == "sgconv":
            self.layer_conv1 = SGConv(num_conv, 2*hidden_dim, activation=activation, name="conv1")
            #self.layer_conv2 = SGConv(num_conv, 2*hidden_dim+len(class_labels), activation=activation, name="conv2")
        elif convlayer == "ghconv":
            self.layer_conv1 = GHConv(num_conv, 2*hidden_dim, activation=activation, name="conv1")
            #self.layer_conv2 = GHConv(num_conv, 2*hidden_dim+len(class_labels), activation=activation, name="conv2")

        # Output layers
        self.layer_id1 = tf.keras.layers.Dense(2*hidden_dim, activation=activation, name="id1")
        self.layer_id2 = tf.keras.layers.Dense(hidden_dim, activation=activation, name="id2")
        #self.layer_id3 = tf.keras.layers.Dense(hidden_dim, activation=activation, name="id3")
        self.layer_id = tf.keras.layers.Dense(nclass_labels, activation="linear", name="out_id")
        #self.layer_charge = tf.keras.layers.Dense(1, activation="linear", name="out_charge")
        
        #self.layer_momentum1 = tf.keras.layers.Dense(2*hidden_dim, activation=activation, name="momentum1")
        #self.layer_momentum2 = tf.keras.layers.Dense(hidden_dim, activation=activation, name="momentum2")
        #self.layer_momentum3 = tf.keras.layers.Dense(hidden_dim, activation=activation, name="momentum3")
        #self.layer_momentum = tf.keras.layers.Dense(3, activation="linear", name="out_momentum")
 
    def predict_distancematrix(self, inputs, training=True):

        x = self.layer_distcoords1(inputs)
        x = self.layer_distcoords2(x)
        #x = self.layer_distcoords3(x)
        distcoords = self.layer_distcoords(x)

        dm = self.layer_dist(distcoords, distcoords)
        
        # masking if the first element is -1
        msk_elem = tf.expand_dims(tf.cast(inputs[:, :, 0] != -1, dtype=tf.float32), -1)
        dm = dm*msk_elem

        return dm

    #@tf.function(input_signature=[tf.TensorSpec(shape=[None, 15], dtype=tf.float32)])
    def call(self, inputs, training=True):
        X = inputs[:,:,1:]
        cl_energies = inputs[:,:,0]
        
        msk_input = tf.expand_dims(tf.cast(X[:, :, 0] != -1, tf.float32), -1)

        dm = self.predict_distancematrix(X, training=training)

        x = self.layer_input1(X)
        x = self.layer_input1_do(x, training)
        x = self.layer_input2(x)
        x = self.layer_input2_do(x, training)
        x = self.layer_input3(x)
        x = self.layer_input3_do(x, training)
        x = self.layer_conv1(x, dm)
        x = self.layer_id1(x)
        x = self.layer_id2(x)
        #x = self.layer_id3(x)
        out_id_logits = self.layer_id(x)
        
        energies = tf.expand_dims(cl_energies, axis=-1)
        # add the cluster energies in the output, in the future we can add here corrections
        output = tf.concat([out_id_logits,energies], axis=-1)
        # mask to 0 the padded output
        output_masked = output * msk_input
        
        #return masked output logits and the predicted total energy
        return output_masked

# %% [markdown]
# # Loss definition

# %%
def separate_true(y, nclass_labels):
    # one-hot encoding for true label (signal,PU,noise)
    # the padded elements have -1 so they are one_hot to (0,0)
    y_onehot = tf.one_hot(tf.cast(y[:,1:], tf.int32), nclass_labels)
    true_en = y[:,0]
    return y_onehot, true_en

def true_mask(y):
    # mask for elements that should be included in supercluster
    in_sc = tf.cast(y[:,1:] == 1., tf.float32)
    # number of padding elements
    padded = tf.reduce_sum(tf.cast(y[:,1:] == -1., tf.float32), axis=-1)
    return in_sc, padded
    
    
def separate_pred(ypred):
    ens = ypred[:,:,2]
    ypred_onehot = ypred[:,:,:2]
    # 0 not include in energy sum, 1 include in energy sum
    # masked elements have pred_id=0 so they do not enter in the energy sum
    pred_id = tf.cast(tf.argmax(ypred_onehot, axis=-1), tf.float32)
    # predicted total energy
    pred_en =  tf.reduce_sum( ens * pred_id, axis=-1)
    # one-hot encoding for true label (signal,PU,noise)
    return ypred_onehot, pred_en, pred_id

# %%
def mse_unreduced(true, pred):
    return tf.math.pow(true-pred,2)

def msle_unreduced(true, pred):
    return tf.math.pow(tf.math.log(tf.math.abs(true) + 1.0) - tf.math.log(tf.math.abs(pred) + 1.0), 2)


#@tf.function
def my_loss_full(y_true, y_pred):
    y_true_onehot, true_en = separate_true(y_true, args.nclass_labels)
    y_pred_onehot, pred_en, pred_id = separate_pred(y_pred)
    # since the padded y_true is -1 -> it gives [0,0] when it is onehot. The ypred for batched is [0,0] so the loss
    # is automatically 0 for padded samples
    l1 = tf.nn.softmax_cross_entropy_with_logits(y_true_onehot, y_pred_onehot)
    
    # true energy loss
    mask_outsc = tf.cast(true_en == 0., tf.float32)
    mask_insc = tf.cast(true_en != 0., tf.float32)
    n_outsc = tf.reduce_sum(mask_outsc)
    n_insc = tf.reduce_sum(mask_insc)
    
    l2_en = mse_unreduced(true_en, pred_en)
    
    # separate mean resolution for windows with Caloparticle or not
    l2_en_outsc = tf.reduce_sum(l2_en * mask_outsc) / n_outsc
    l2_en_insc = tf.reduce_sum(l2_en * mask_insc) / n_insc
    
    ltot = 1e4*tf.reduce_mean(l1) + 20* l2_en_insc + 10* l2_en_outsc
    
    return ltot

# %%
def energy_resolution_outsc(y_true, y_pred):
    y_true_onehot, true_en = separate_true(y_true, args.nclass_labels)
    y_pred_onehot, pred_en, pred_id = separate_pred(y_pred)
    mask_outsc = tf.cast(true_en == 0., tf.float32)
    n_outsc = tf.reduce_sum(mask_outsc)
    
    return tf.reduce_sum(mse_unreduced(true_en, pred_en)*mask_outsc) / n_outsc

def energy_resolution_insc(y_true, y_pred):
    y_true_onehot, true_en = separate_true(y_true, args.nclass_labels)
    y_pred_onehot, pred_en, pred_id = separate_pred(y_pred)
    mask_insc = tf.cast(true_en != 0., tf.float32)
    n_insc = tf.reduce_sum(mask_insc)
    
    return tf.reduce_sum(mse_unreduced(true_en, pred_en)*mask_insc) / n_insc

# %%
def get_tpfn_metrics(y_true, y_pred):
    y_true_mask, n_padded = true_mask(y_true)
    y_false_mask = (tf.cast(y_true_mask == 0., tf.float32))
    
    # pred_id contains the last n_padded elements to 0 that will be always True negatives
    y_pred_onehot, pred_en, pred_id = separate_pred(y_pred)
    
    n_pos = tf.reduce_sum(y_true_mask, axis=-1)
    n_neg = tf.reduce_sum(y_false_mask, axis=-1) - n_padded
    
    n_tot = n_neg + n_pos
    
    true_pos = tf.reduce_sum(pred_id * y_true_mask, axis=-1)
    false_neg = n_pos - true_pos
    
    false_pos = tf.reduce_sum(pred_id * y_false_mask, axis=-1)
    true_neg = n_neg - false_pos
    
    return n_tot, true_pos, false_neg, false_pos, true_neg,

# %%
def precision(tp,tn,fp,fn):
    return tp/(tp+fp)

def recall(tp,tn,fp,fn):
    return tp/(tp+fn)

def accuracy(tp,tn,fp,fn):
    return (tp+tn)/(tp+tn+fp+fn)

# %%
class Precision(tf.keras.metrics.Metric):

    def __init__(self, name='precision', **kwargs):
        super(Precision, self).__init__(name=name, **kwargs)
        self.tp = self.add_weight(name='tp', initializer='zeros')
        self.fp = self.add_weight(name='fp', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        n_tot, true_pos, false_neg, false_pos, true_neg = get_tpfn_metrics(y_true, y_pred)
        self.tp.assign_add(tf.reduce_sum(true_pos))
        self.fp.assign_add(tf.reduce_sum(false_pos))

    def result(self):
        return self.tp / (self.tp + self.fp)

    def reset_states(self):
        self.tp.assign(0)
        self.fp.assign(0)
        
class Recall(tf.keras.metrics.Metric):

    def __init__(self, name='recall', **kwargs):
        super(Recall, self).__init__(name=name, **kwargs)
        self.tp = self.add_weight(name='tp', initializer='zeros')
        self.fn = self.add_weight(name='fn', initializer='zeros')

    def update_state(self, y_true, y_pred, sample_weight=None):
        n_tot, true_pos, false_neg, false_pos, true_neg = get_tpfn_metrics(y_true, y_pred)
        self.tp.assign_add(tf.reduce_sum(true_pos))
        self.fn.assign_add(tf.reduce_sum(false_neg))

    def result(self):
        return self.tp / (self.tp + self.fn)

    def reset_states(self):
        self.tp.assign(0)
        self.fn.assign(0)

# %% [markdown]
# ### Settings

# %%
data_path = "/storage/ECAL/training_data/window_data/electrons/recordio_v4"
models_path = "/storage/ECAL/deepcluster/models/gcn_models_v6/"

#rain_steps_per_epoch = 
#eval_steps_per_epoch = 3e5 // batch_size
from collections import namedtuple
Args = namedtuple('args', [ 'models_path', 'load','nepochs','ntrain','nval','nfeatures',
                            'n_seed_features','batch_size','lr_decay','lr',
                            'nhidden','distance_dim','num_conv','dropout','convlayer',
                           'nclass_labels', 'opt'])

args = Args( 
        models_path = models_path,
        load = False,
        nepochs = 100,
        ntrain = 50000,
        nval = 10000,
        batch_size = 65,
        nfeatures = 13,
        n_seed_features = 12,
        lr_decay = 0,
        lr = 0.0001,
        nhidden = 128,
        distance_dim = 100,
        num_conv = 2,
        dropout = 0.05,
        convlayer = 'ghconv',
        nclass_labels=2,
        opt='adam'
        )

# %% [markdown]
# ### Dataset loading

# %%
def scale_features_clusters(X):
    '''
    'is_seed',"cluster_deta", "cluster_dphi", "en_cluster", "et_cluster",
    "cl_f5_r9", "cl_f5_sigmaIetaIeta","cl_f5_sigmaIetaIphi","cl_f5_sigmaIphiIphi",
    "cl_f5_swissCross", "cl_nxtals", "cl_etaWidth", "cl_phiWidth
    '''
    x_mean = tf.constant( 
        [   0.,  -7.09402501e-04, -1.27142875e-04,  1.30375508e+00,  5.67249500e-01, 
            1.92096066e+00,  1.31476120e-02,  1.62948213e-05,  1.42948806e-02,
            5.92920497e-01,  1.49597644e+00,  3.36213188e-03,  3.06446267e-03]
        )

    x_scale = tf.constant(
        [  1.,  1.10279784e-01, 3.30488055e-01, 2.62605247e+00, 1.16284769e+00,
            7.81094814e+00, 1.70392176e-02, 3.05995567e-04, 1.80176053e-02,
            1.99316624e+00, 1.88845046e+00, 4.12315715e-03, 4.79639033e-03]       
        )
    return (X-x_mean)/ x_scale

def scale_features_seed(X):
    '''
     "seed_eta", "seed_iz","en_seed","et_seed",
     "seed_f5_r9", "seed_f5_sigmaIetaIeta","seed_f5_sigmaIetaIphi","seed_f5_sigmaIphiIphi",
     "seed_f5_swissCross","seed_nxtals", "seed_etaWidth", "seed_phiWidth",
    '''
    x_mean = tf.constant( 
        [   6.84241156e-03,  1.62242679e-03,  5.81495577e+01,  2.57215845e+01, 
            1.00772582e+00,  1.35803461e-02, -4.29317013e-06,  1.71072024e-02,
            4.90466869e-01,  5.10511982e+00,  8.82101138e-03,  1.04095965e-02 ]
    
        )

    x_scale = tf.constant(
        [   1.31333380e+00, 5.06988411e-01, 9.21157365e+01, 2.98580765e+01, 
            1.17047757e-01, 1.11969442e-02, 1.86572967e-04, 1.31036359e-02,
            4.01511744e-01, 5.67007350e+00, 6.14304203e-03, 7.24808860e-03]       
        )
    return (X-x_mean)/ x_scale

# %%
def _parse_tfr_element(element):
    parse_dic = {
        'X':      tf.io.FixedLenFeature([], tf.string),
        'X_seed': tf.io.FixedLenFeature([], tf.string),
        'y':      tf.io.FixedLenFeature([], tf.string),
        'n_clusters': tf.io.FixedLenFeature([], tf.int64)
    }
    example_message = tf.io.parse_single_example(element, parse_dic)

    X = example_message['X']
    X_seed = example_message['X_seed']
    y = example_message['y']
    nclusters = example_message['n_clusters']
    
    arr_X = tf.io.parse_tensor(X, out_type=tf.float32)
    arr_X_seed = tf.io.parse_tensor(X_seed, out_type=tf.float32)
    arr_y = tf.io.parse_tensor(y, out_type=tf.float32)
    
    #https://github.com/tensorflow/tensorflow/issues/24520#issuecomment-577325475
    arr_X.set_shape(     tf.TensorShape((None, args.nfeatures)))
    arr_X_seed.set_shape(tf.TensorShape((1, args.n_seed_features)))
    arr_y.set_shape(     tf.TensorShape((None,)))
 
    return arr_X, arr_X_seed, nclusters, arr_y
  
def _stack_seed_features(arr_X, arr_X_seed, nclusters, arr_y):
    en_clusters = tf.expand_dims(arr_X[:,3], axis=-1)
    rescaled_X = scale_features_clusters(arr_X)
    rescaled_X_seed = scale_features_seed(arr_X_seed)
    X = tf.concat([en_clusters, rescaled_X, tf.broadcast_to(rescaled_X_seed,[nclusters,rescaled_X_seed.shape[1]] )],
                  axis=1)
    return X,arr_y

# %%
# padding shape
ps = ([None,args.nfeatures+args.n_seed_features+1],[None,])

# Create datasets from TFRecord files.
dataset = tf.data.TFRecordDataset(tf.io.gfile.glob('{}/training-*'.format(data_path)))
dataset = dataset.map(_parse_tfr_element,num_parallel_calls=tf.data.experimental.AUTOTUNE)
dataset = dataset.map(_stack_seed_features,num_parallel_calls=tf.data.experimental.AUTOTUNE) # deterministic=False in TFv2.3
dataset = dataset.shuffle(10000, reshuffle_each_iteration=True)

ds_train = dataset.take(args.ntrain).padded_batch(args.batch_size, padded_shapes=ps, drop_remainder=True,padding_values=(-1.,-1.))
ds_test = dataset.skip(args.ntrain).take(args.nval).padded_batch(args.batch_size, padded_shapes=ps, drop_remainder=True,padding_values=(-1.,-1.))

ds_train_r = ds_train.repeat(args.nepochs)
ds_test_r = ds_test.repeat(args.nepochs)

# %%
idata = iter(dataset)
d = next(idata)

# %%
d[1]
# Out:
# <tf.Tensor: shape=(2,), dtype=float32, numpy=array([653.773,   1.   ], dtype=float32)>

# %%
def get_unique_run():
    previous_runs = os.listdir(args.models_path)
    if len(previous_runs) == 0:
        run_number = 1
    else:
        run_number = max([int(s.split('run_')[1]) for s in previous_runs]) + 1
    return run_number

# %%
if args.lr_decay > 0:
        lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
            args.lr,
            decay_steps=3*int(args.ntrain//args.batch_size),
            decay_rate=args.lr_decay
        )
else:
    lr_schedule = args.lr

# %%
with strategy.scope():
    opt = tf.keras.optimizers.Adam(learning_rate=lr_schedule)
    
    model = DNNSuperCluster(hidden_dim=args.nhidden, nclass_labels=args.nclass_labels, distance_dim=args.distance_dim, 
                            num_conv=args.num_conv, convlayer=args.convlayer, dropout=args.dropout)

# %%
if not os.path.isdir(args.models_path):
    os.makedirs(args.models_path)

name =  'run_{:02}'.format(get_unique_run())

outdir = args.models_path + name

if os.path.isdir(outdir):
    print("Output directory exists: {}".format(outdir), file=sys.stderr)

print(outdir)
# Out:
# /storage/ECAL/deepcluster/models/gcn_models_v6/run_02
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-ae598c323fa4> in <module>
#      11 print(outdir)
#      12
# ---> 13 with open(outdir + "/args.txt",'w') as config:
#      14     config.write(str(args))
#      15
#
# FileNotFoundError: [Errno 2] No such file or directory: '/storage/ECAL/deepcluster/models/gcn_models_v6/run_02/args.txt'

# %%
callbacks = []
tb = tf.keras.callbacks.TensorBoard(
    log_dir=outdir, histogram_freq=3, 
    write_graph=False, 
    write_images=True,
    update_freq='epoch',
    embeddings_freq = 3 ,
    #profile_batch=(10,90),
    profile_batch=0,
)
tb.set_model(model)
callbacks += [tb]

terminate_cb = tf.keras.callbacks.TerminateOnNaN()
callbacks += [terminate_cb]

cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=outdir + "/weights.{epoch:02d}-{val_loss:.6f}.hdf5",
    save_weights_only=True,
    verbose=0
)
cp_callback.set_model(model)
callbacks += [cp_callback]

loss_fn = my_loss_full

# %%
with strategy.scope():
    model.compile(optimizer=args.opt, loss=loss_fn,
        metrics=[Precision(),Recall(), energy_resolution_insc,energy_resolution_outsc])

    for X, y in ds_train:
        ypred = model(X)
        l = loss_fn(y, ypred)
        break

# %%
yoh,true_en = separate_true(y, args.nclass_labels)

# %%
ypred
# Out:
# <tf.Tensor: shape=(65, 20, 3), dtype=float32, numpy=
# array([[[-9.3360847e-01,  1.2688243e+00,  2.5694809e+02],
#         [ 1.7077485e+00,  2.5672934e+00,  2.4727177e+01],
#         [-0.0000000e+00,  0.0000000e+00, -0.0000000e+00],
#         ...,
#         [-0.0000000e+00,  0.0000000e+00, -0.0000000e+00],
#         [-0.0000000e+00,  0.0000000e+00, -0.0000000e+00],
#         [-0.0000000e+00,  0.0000000e+00, -0.0000000e+00]],
#
#        [[ 2.1486759e+00,  1.6870821e+00,  2.8743708e+01],
#         [ 1.1384740e+00,  1.7773858e-01,  1.2126850e+01],
#         [ 3.3191218e+00, -6.3352406e-01,  4.3744545e+00],
#         ...,
#         [-0.0000000e+00,  0.0000000e+00, -0.0000000e+00],
#         [-0.0000000e+00,  0.0000000e+00, -0.0000000e+00],
#         [-0.0000000e+00,  0.0000000e+00, -0.0000000e+00]],
#
#        [[ 2.1340659e+00, -3.7977490e-01,  3.5081942e+00],
#         [ 7.4043041e-01,  7.1921480e-01,  3.0454373e+00],
#         [ 1.8406001e+00,  1.5196750e+00,  2.6385665e+00],
#         ...,
#         [-0.0000000e+00,  0.0000000e+00, -0.0000000e+00],
#         [-0.0000000e+00,  0.0000000e+00, -0.0000000e+00],
#         [-0.0000000e+00,  0.0000000e+00, -0.0000000e+00]],
#
#        ...,
#
#        [[-1.0707178e+00, -2.1470084e+00,  5.1450300e+00],
#         [-0.0000000e+00,  0.0000000e+00, -0.0000000e+00],
#         [-0.0000000e+00,  0.0000000e+00, -0.0000000e+00],
#         ...,
#         [-0.0000000e+00,  0.0000000e+00, -0.0000000e+00],
#         [-0.0000000e+00,  0.0000000e+00, -0.0000000e+00],
#         [-0.0000000e+00,  0.0000000e+00, -0.0000000e+00]],
#
#        [[ 2.6728754e+00,  1.1659158e+00,  4.9788175e+00],
#         [ 5.6870377e-01,  3.2617569e-01,  2.5102239e+00],
#         [-1.2070099e+00,  1.4561780e-01,  1.4063915e+00],
#         ...,
#         [-0.0000000e+00,  0.0000000e+00, -0.0000000e+00],
#         [-0.0000000e+00,  0.0000000e+00, -0.0000000e+00],
#         [-0.0000000e+00,  0.0000000e+00, -0.0000000e+00]],
#
#        [[-4.6343517e+00,  2.2884526e+00,  2.2294617e+02],
#         [ 1.7628951e+00,  1.3015683e-01,  3.7245028e+00],
#         [ 1.4141934e+00,  4.5165235e-01,  3.7689486e+00],
#         ...,
#         [-0.0000000e+00,  0.0000000e+00, -0.0000000e+00],
#         [-0.0000000e+00,  0.0000000e+00, -0.0000000e+00],
#         [-0.0000000e+00,  0.0000000e+00, -0.0000000e+00]]], dtype=float32)>

# %%
model.summary()
# Out:
# Model: "dnn_super_cluster"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# distcoords1 (Dense)          multiple                  3328
# _________________________________________________________________
# distcoords2 (Dense)          multiple                  16512
# _________________________________________________________________
# distcoords (Dense)           multiple                  12900
# _________________________________________________________________
# input1 (Dense)               multiple                  3328
# _________________________________________________________________
# dropout (Dropout)            multiple                  0
# _________________________________________________________________
# input2 (Dense)               multiple                  16512
# _________________________________________________________________
# dropout_1 (Dropout)          multiple                  0
# _________________________________________________________________
# input3 (Dense)               multiple                  33024
# _________________________________________________________________
# dropout_2 (Dropout)          multiple                  0
# _________________________________________________________________
# distance (Distance)          multiple                  0
# _________________________________________________________________
# conv1 (GHConv)               multiple                  196864
# _________________________________________________________________
# id1 (Dense)                  multiple                  65792
# _________________________________________________________________
# id2 (Dense)                  multiple                  32896
# _________________________________________________________________
# out_id (Dense)               multiple                  258
# =================================================================
# Total params: 381,414
# Trainable params: 381,414
# Non-trainable params: 0
# _________________________________________________________________

# %%
if args.load:
    #ensure model input size is known
    for X, y in ds_train:
        model(X)
        break

    model.load_weights(args.load)
if args.nepochs > 0:
    ret = model.fit(ds_train_r,
        validation_data=ds_test_r, epochs=args.nepochs,
        steps_per_epoch=args.ntrain//args.batch_size, validation_steps=args.nval//args.batch_size,
        verbose=True,
        callbacks=callbacks
    )
# Out:
# Train for 769 steps, validate for 153 steps
# Epoch 1/100
# 769/769 [==============================] - 29s 38ms/step - loss: 1304.4699 - precision: 0.9033 - recall: 0.7966 - energy_resolution_insc: 38.7336 - energy_resolution_outsc: 12.6357 - val_loss: 646.8611 - val_precision: 0.9201 - val_recall: 0.8404 - val_energy_resolution_insc: 9.7199 - val_energy_resolution_outsc: 13.9464
# Epoch 2/100
# 769/769 [==============================] - 21s 27ms/step - loss: 833.6771 - precision: 0.9159 - recall: 0.8364 - energy_resolution_insc: 19.9507 - energy_resolution_outsc: 11.4838 - val_loss: 656.7403 - val_precision: 0.9309 - val_recall: 0.8447 - val_energy_resolution_insc: 13.4899 - val_energy_resolution_outsc: 9.5620
# Epoch 3/100
# 769/769 [==============================] - 21s 27ms/step - loss: 1444.3208 - precision: 0.9198 - recall: 0.8439 - energy_resolution_insc: 50.5437 - energy_resolution_outsc: 12.8327 - val_loss: 653.1045 - val_precision: 0.8941 - val_recall: 0.8794 - val_energy_resolution_insc: 10.8702 - val_energy_resolution_outsc: 12.5796
# Epoch 4/100
# 769/769 [==============================] - 20s 26ms/step - loss: 734.3411 - precision: 0.9226 - recall: 0.8510 - energy_resolution_insc: 16.3499 - energy_resolution_outsc: 11.6350 - val_loss: 591.5251 - val_precision: 0.9205 - val_recall: 0.8598 - val_energy_resolution_insc: 11.7501 - val_energy_resolution_outsc: 6.4392
# Epoch 5/100
# 769/769 [==============================] - 22s 28ms/step - loss: 735.0344 - precision: 0.9238 - recall: 0.8536 - energy_resolution_insc: 16.5310 - energy_resolution_outsc: 11.7115 - val_loss: 642.8692 - val_precision: 0.9230 - val_recall: 0.8526 - val_energy_resolution_insc: 12.9705 - val_energy_resolution_outsc: 9.5083
# Epoch 6/100
# 769/769 [==============================] - 21s 27ms/step - loss: 839.2394 - precision: 0.9270 - recall: 0.8549 - energy_resolution_insc: 22.5304 - energy_resolution_outsc: 10.9523 - val_loss: 605.6446 - val_precision: 0.9351 - val_recall: 0.8477 - val_energy_resolution_insc: 10.3621 - val_energy_resolution_outsc: 11.3094
# Epoch 7/100
# 769/769 [==============================] - 20s 26ms/step - loss: 680.2120 - precision: 0.9286 - recall: 0.8584 - energy_resolution_insc: 14.0886 - energy_resolution_outsc: 12.1039 - val_loss: 601.5688 - val_precision: 0.9291 - val_recall: 0.8627 - val_energy_resolution_insc: 15.0477 - val_energy_resolution_outsc: 3.5979
# Epoch 8/100
# 769/769 [==============================] - 22s 28ms/step - loss: 1052.4597 - precision: 0.9286 - recall: 0.8591 - energy_resolution_insc: 33.1657 - energy_resolution_outsc: 11.2162 - val_loss: 619.1158 - val_precision: 0.9371 - val_recall: 0.8410 - val_energy_resolution_insc: 14.1095 - val_energy_resolution_outsc: 5.8892
# Epoch 9/100
# 769/769 [==============================] - 21s 27ms/step - loss: 662.1485 - precision: 0.9292 - recall: 0.8618 - energy_resolution_insc: 14.0181 - energy_resolution_outsc: 11.2095 - val_loss: 522.8118 - val_precision: 0.9221 - val_recall: 0.8694 - val_energy_resolution_insc: 6.2544 - val_energy_resolution_outsc: 13.0459
# Epoch 10/100
# 769/769 [==============================] - 20s 26ms/step - loss: 684.8215 - precision: 0.9298 - recall: 0.8621 - energy_resolution_insc: 14.7955 - energy_resolution_outsc: 11.8729 - val_loss: 486.7096 - val_precision: 0.9383 - val_recall: 0.8604 - val_energy_resolution_insc: 9.1944 - val_energy_resolution_outsc: 4.6464
# Epoch 11/100
# 769/769 [==============================] - 22s 28ms/step - loss: 735.7474 - precision: 0.9312 - recall: 0.8637 - energy_resolution_insc: 18.1444 - energy_resolution_outsc: 10.5464 - val_loss: 500.1938 - val_precision: 0.9303 - val_recall: 0.8644 - val_energy_resolution_insc: 7.9952 - val_energy_resolution_outsc: 6.5081
# Epoch 12/100
# 769/769 [==============================] - 21s 27ms/step - loss: 651.5382 - precision: 0.9311 - recall: 0.8645 - energy_resolution_insc: 13.8000 - energy_resolution_outsc: 10.7984 - val_loss: 530.8028 - val_precision: 0.9223 - val_recall: 0.8721 - val_energy_resolution_insc: 7.8652 - val_energy_resolution_outsc: 9.9978
# Epoch 13/100
# 769/769 [==============================] - 20s 26ms/step - loss: 680.6978 - precision: 0.9311 - recall: 0.8667 - energy_resolution_insc: 15.9031 - energy_resolution_outsc: 10.0464 - val_loss: 521.2818 - val_precision: 0.9218 - val_recall: 0.8789 - val_energy_resolution_insc: 7.3366 - val_energy_resolution_outsc: 10.4983
# Epoch 14/100
# 769/769 [==============================] - 21s 28ms/step - loss: 638.2317 - precision: 0.9317 - recall: 0.8670 - energy_resolution_insc: 13.7946 - energy_resolution_outsc: 10.1222 - val_loss: 501.2458 - val_precision: 0.9387 - val_recall: 0.8645 - val_energy_resolution_insc: 6.1686 - val_energy_resolution_outsc: 11.6929
# Epoch 15/100
# 769/769 [==============================] - 21s 27ms/step - loss: 652.8878 - precision: 0.9322 - recall: 0.8678 - energy_resolution_insc: 14.3172 - energy_resolution_outsc: 10.7734 - val_loss: 565.5249 - val_precision: 0.8969 - val_recall: 0.8936 - val_energy_resolution_insc: 9.3450 - val_energy_resolution_outsc: 10.7771
# Epoch 16/100
# 769/769 [==============================] - 19s 25ms/step - loss: 637.1565 - precision: 0.9339 - recall: 0.8687 - energy_resolution_insc: 13.8495 - energy_resolution_outsc: 10.3862 - val_loss: 588.7905 - val_precision: 0.9237 - val_recall: 0.8790 - val_energy_resolution_insc: 10.9567 - val_energy_resolution_outsc: 11.2218
# Epoch 17/100
# 769/769 [==============================] - 22s 28ms/step - loss: 648.8140 - precision: 0.9334 - recall: 0.8699 - energy_resolution_insc: 13.9359 - energy_resolution_outsc: 11.5485 - val_loss: 504.7339 - val_precision: 0.9382 - val_recall: 0.8722 - val_energy_resolution_insc: 7.7424 - val_energy_resolution_outsc: 10.7683
# Epoch 18/100
# 769/769 [==============================] - 21s 27ms/step - loss: 654.4433 - precision: 0.9339 - recall: 0.8722 - energy_resolution_insc: 14.6980 - energy_resolution_outsc: 10.7223 - val_loss: 513.2405 - val_precision: 0.9357 - val_recall: 0.8697 - val_energy_resolution_insc: 8.7559 - val_energy_resolution_outsc: 8.1340
# Epoch 19/100
# 769/769 [==============================] - 19s 25ms/step - loss: 681.0232 - precision: 0.9336 - recall: 0.8715 - energy_resolution_insc: 16.5883 - energy_resolution_outsc: 9.7600 - val_loss: 563.8358 - val_precision: 0.9448 - val_recall: 0.8584 - val_energy_resolution_insc: 7.6490 - val_energy_resolution_outsc: 15.2238
# Epoch 20/100
# 769/769 [==============================] - 22s 28ms/step - loss: 608.7573 - precision: 0.9352 - recall: 0.8712 - energy_resolution_insc: 12.8296 - energy_resolution_outsc: 10.2148 - val_loss: 516.5871 - val_precision: 0.9276 - val_recall: 0.8748 - val_energy_resolution_insc: 7.8142 - val_energy_resolution_outsc: 8.5233
# Epoch 21/100
# 769/769 [==============================] - 21s 27ms/step - loss: 621.2886 - precision: 0.9329 - recall: 0.8736 - energy_resolution_insc: 13.0729 - energy_resolution_outsc: 11.1194 - val_loss: 571.2156 - val_precision: 0.9729 - val_recall: 0.8135 - val_energy_resolution_insc: 10.0383 - val_energy_resolution_outsc: 9.2542
# Epoch 22/100
# 769/769 [==============================] - 19s 25ms/step - loss: 620.5824 - precision: 0.9358 - recall: 0.8747 - energy_resolution_insc: 13.3797 - energy_resolution_outsc: 10.7520 - val_loss: 450.9023 - val_precision: 0.9356 - val_recall: 0.8740 - val_energy_resolution_insc: 7.5294 - val_energy_resolution_outsc: 5.3754
# Epoch 23/100
# 769/769 [==============================] - 22s 28ms/step - loss: 991.8364 - precision: 0.9366 - recall: 0.8728 - energy_resolution_insc: 32.5891 - energy_resolution_outsc: 9.2902 - val_loss: 516.8307 - val_precision: 0.9381 - val_recall: 0.8683 - val_energy_resolution_insc: 10.0777 - val_energy_resolution_outsc: 6.3347
# Epoch 24/100
# 769/769 [==============================] - 21s 27ms/step - loss: 610.5507 - precision: 0.9359 - recall: 0.8760 - energy_resolution_insc: 12.8567 - energy_resolution_outsc: 10.8121 - val_loss: 426.8295 - val_precision: 0.9303 - val_recall: 0.8843 - val_energy_resolution_insc: 5.9596 - val_energy_resolution_outsc: 6.2100
# Epoch 25/100
# 769/769 [==============================] - 21s 27ms/step - loss: 601.0448 - precision: 0.9391 - recall: 0.8742 - energy_resolution_insc: 12.7217 - energy_resolution_outsc: 10.4337 - val_loss: 546.2625 - val_precision: 0.9420 - val_recall: 0.8621 - val_energy_resolution_insc: 10.9166 - val_energy_resolution_outsc: 7.1664
# Epoch 26/100
# 769/769 [==============================] - 21s 27ms/step - loss: 621.8096 - precision: 0.9377 - recall: 0.8716 - energy_resolution_insc: 13.7248 - energy_resolution_outsc: 10.4572 - val_loss: 570.5153 - val_precision: 0.9487 - val_recall: 0.8614 - val_energy_resolution_insc: 8.9873 - val_energy_resolution_outsc: 14.1597
# Epoch 27/100
# 769/769 [==============================] - 21s 27ms/step - loss: 612.5254 - precision: 0.9377 - recall: 0.8736 - energy_resolution_insc: 13.9549 - energy_resolution_outsc: 9.2626 - val_loss: 497.8852 - val_precision: 0.9252 - val_recall: 0.8805 - val_energy_resolution_insc: 7.8292 - val_energy_resolution_outsc: 8.1409
# Epoch 28/100
# 769/769 [==============================] - 19s 25ms/step - loss: 627.5050 - precision: 0.9385 - recall: 0.8747 - energy_resolution_insc: 14.2643 - energy_resolution_outsc: 10.2542 - val_loss: 428.5460 - val_precision: 0.9388 - val_recall: 0.8770 - val_energy_resolution_insc: 6.3073 - val_energy_resolution_outsc: 6.4115
# Epoch 29/100
# 769/769 [==============================] - 22s 28ms/step - loss: 589.4082 - precision: 0.9390 - recall: 0.8762 - energy_resolution_insc: 12.1450 - energy_resolution_outsc: 10.9120 - val_loss: 467.8678 - val_precision: 0.9418 - val_recall: 0.8654 - val_energy_resolution_insc: 7.1541 - val_energy_resolution_outsc: 7.1335
# Epoch 30/100
# 769/769 [==============================] - 22s 28ms/step - loss: 617.0951 - precision: 0.9413 - recall: 0.8737 - energy_resolution_insc: 13.9604 - energy_resolution_outsc: 10.0798 - val_loss: 491.8961 - val_precision: 0.9339 - val_recall: 0.8698 - val_energy_resolution_insc: 6.9572 - val_energy_resolution_outsc: 9.6213
# Epoch 31/100
# 769/769 [==============================] - 24s 32ms/step - loss: 599.1489 - precision: 0.9401 - recall: 0.8753 - energy_resolution_insc: 13.1194 - energy_resolution_outsc: 10.0219 - val_loss: 472.6782 - val_precision: 0.9419 - val_recall: 0.8740 - val_energy_resolution_insc: 8.0762 - val_energy_resolution_outsc: 6.4913
# Epoch 32/100
# 769/769 [==============================] - 22s 28ms/step - loss: 589.1350 - precision: 0.9391 - recall: 0.8749 - energy_resolution_insc: 12.2388 - energy_resolution_outsc: 11.0310 - val_loss: 478.5640 - val_precision: 0.9284 - val_recall: 0.8855 - val_energy_resolution_insc: 7.9147 - val_energy_resolution_outsc: 7.2303
# Epoch 33/100
# 769/769 [==============================] - 20s 25ms/step - loss: 571.0846 - precision: 0.9411 - recall: 0.8778 - energy_resolution_insc: 12.0110 - energy_resolution_outsc: 10.0102 - val_loss: 555.7304 - val_precision: 0.9385 - val_recall: 0.8722 - val_energy_resolution_insc: 7.8172 - val_energy_resolution_outsc: 14.5662
# Epoch 34/100
# 769/769 [==============================] - 22s 29ms/step - loss: 942.7472 - precision: 0.9406 - recall: 0.8784 - energy_resolution_insc: 30.1409 - energy_resolution_outsc: 10.7618 - val_loss: 502.8436 - val_precision: 0.9300 - val_recall: 0.8790 - val_energy_resolution_insc: 8.2448 - val_energy_resolution_outsc: 9.2438
# Epoch 35/100
# 769/769 [==============================] - 21s 28ms/step - loss: 590.3503 - precision: 0.9412 - recall: 0.8774 - energy_resolution_insc: 12.2807 - energy_resolution_outsc: 11.1081 - val_loss: 454.3132 - val_precision: 0.9173 - val_recall: 0.8990 - val_energy_resolution_insc: 6.3401 - val_energy_resolution_outsc: 7.7388
# Epoch 36/100
# 769/769 [==============================] - 20s 26ms/step - loss: 741.6035 - precision: 0.9401 - recall: 0.8798 - energy_resolution_insc: 20.1854 - energy_resolution_outsc: 10.7018 - val_loss: 471.3999 - val_precision: 0.9380 - val_recall: 0.8800 - val_energy_resolution_insc: 6.3516 - val_energy_resolution_outsc: 10.0961
# Epoch 37/100
# 769/769 [==============================] - 22s 29ms/step - loss: 576.3463 - precision: 0.9423 - recall: 0.8788 - energy_resolution_insc: 12.3406 - energy_resolution_outsc: 10.0971 - val_loss: 446.3833 - val_precision: 0.9462 - val_recall: 0.8718 - val_energy_resolution_insc: 6.2873 - val_energy_resolution_outsc: 8.3859
# Epoch 38/100
# 769/769 [==============================] - 21s 28ms/step - loss: 1043.0201 - precision: 0.9399 - recall: 0.8801 - energy_resolution_insc: 35.8736 - energy_resolution_outsc: 9.6445 - val_loss: 502.1820 - val_precision: 0.9394 - val_recall: 0.8721 - val_energy_resolution_insc: 7.6337 - val_energy_resolution_outsc: 10.5022
# Epoch 39/100
# 769/769 [==============================] - 19s 25ms/step - loss: 563.4420 - precision: 0.9425 - recall: 0.8826 - energy_resolution_insc: 11.7616 - energy_resolution_outsc: 10.1428 - val_loss: 473.2637 - val_precision: 0.9373 - val_recall: 0.8753 - val_energy_resolution_insc: 8.0124 - val_energy_resolution_outsc: 6.3122
# Epoch 40/100
# 769/769 [==============================] - 22s 28ms/step - loss: 784.1659 - precision: 0.9420 - recall: 0.8806 - energy_resolution_insc: 23.2744 - energy_resolution_outsc: 9.2817 - val_loss: 492.6565 - val_precision: 0.9514 - val_recall: 0.8641 - val_energy_resolution_insc: 8.2573 - val_energy_resolution_outsc: 8.6887
# Epoch 41/100
# 769/769 [==============================] - 21s 28ms/step - loss: 710.4402 - precision: 0.9403 - recall: 0.8825 - energy_resolution_insc: 18.9229 - energy_resolution_outsc: 10.7576 - val_loss: 462.1987 - val_precision: 0.9581 - val_recall: 0.8498 - val_energy_resolution_insc: 8.3043 - val_energy_resolution_outsc: 4.7548
# Epoch 42/100
# 769/769 [==============================] - 19s 25ms/step - loss: 572.9718 - precision: 0.9413 - recall: 0.8818 - energy_resolution_insc: 11.9144 - energy_resolution_outsc: 10.7708 - val_loss: 439.9553 - val_precision: 0.9442 - val_recall: 0.8711 - val_energy_resolution_insc: 5.5399 - val_energy_resolution_outsc: 8.9702
# Epoch 43/100
# 769/769 [==============================] - 22s 29ms/step - loss: 571.7890 - precision: 0.9431 - recall: 0.8836 - energy_resolution_insc: 12.1521 - energy_resolution_outsc: 10.5308 - val_loss: 447.5220 - val_precision: 0.9440 - val_recall: 0.8754 - val_energy_resolution_insc: 6.1556 - val_energy_resolution_outsc: 8.1303
# Epoch 44/100
# 769/769 [==============================] - 21s 28ms/step - loss: 560.6473 - precision: 0.9439 - recall: 0.8824 - energy_resolution_insc: 12.0501 - energy_resolution_outsc: 9.5923 - val_loss: 418.3589 - val_precision: 0.9186 - val_recall: 0.8965 - val_energy_resolution_insc: 4.5829 - val_energy_resolution_outsc: 7.3165
# Epoch 45/100
# 769/769 [==============================] - 21s 28ms/step - loss: 558.2048 - precision: 0.9435 - recall: 0.8822 - energy_resolution_insc: 11.3055 - energy_resolution_outsc: 10.7697 - val_loss: 483.4227 - val_precision: 0.9535 - val_recall: 0.8579 - val_energy_resolution_insc: 7.8382 - val_energy_resolution_outsc: 8.1881
# Epoch 46/100
# 769/769 [==============================] - 22s 29ms/step - loss: 557.1262 - precision: 0.9440 - recall: 0.8845 - energy_resolution_insc: 11.6656 - energy_resolution_outsc: 10.2531 - val_loss: 461.0314 - val_precision: 0.9205 - val_recall: 0.8915 - val_energy_resolution_insc: 7.6843 - val_energy_resolution_outsc: 5.9684
# Epoch 47/100
# 769/769 [==============================] - 22s 28ms/step - loss: 576.1713 - precision: 0.9433 - recall: 0.8830 - energy_resolution_insc: 13.0243 - energy_resolution_outsc: 9.4102 - val_loss: 471.5515 - val_precision: 0.9337 - val_recall: 0.8803 - val_energy_resolution_insc: 7.1748 - val_energy_resolution_outsc: 8.2151
# Epoch 48/100
# 769/769 [==============================] - 21s 28ms/step - loss: 559.6791 - precision: 0.9410 - recall: 0.8867 - energy_resolution_insc: 11.8472 - energy_resolution_outsc: 10.2539 - val_loss: 507.1136 - val_precision: 0.9419 - val_recall: 0.8784 - val_energy_resolution_insc: 9.7397 - val_energy_resolution_outsc: 6.6461
# Epoch 49/100
# 769/769 [==============================] - 21s 28ms/step - loss: 567.0485 - precision: 0.9442 - recall: 0.8843 - energy_resolution_insc: 12.9628 - energy_resolution_outsc: 8.8596 - val_loss: 436.6817 - val_precision: 0.9351 - val_recall: 0.8906 - val_energy_resolution_insc: 7.5473 - val_energy_resolution_outsc: 4.9801
# Epoch 50/100
# 769/769 [==============================] - 20s 26ms/step - loss: 605.2667 - precision: 0.9457 - recall: 0.8859 - energy_resolution_insc: 14.3664 - energy_resolution_outsc: 10.0619 - val_loss: 520.8519 - val_precision: 0.9633 - val_recall: 0.8467 - val_energy_resolution_insc: 12.0351 - val_energy_resolution_outsc: 3.7637
# Epoch 51/100
# 769/769 [==============================] - 22s 29ms/step - loss: 549.7052 - precision: 0.9431 - recall: 0.8851 - energy_resolution_insc: 11.4942 - energy_resolution_outsc: 10.4697 - val_loss: 503.6279 - val_precision: 0.8946 - val_recall: 0.9158 - val_energy_resolution_insc: 5.9160 - val_energy_resolution_outsc: 12.7783
# Epoch 52/100
# 769/769 [==============================] - 22s 28ms/step - loss: 559.6274 - precision: 0.9444 - recall: 0.8873 - energy_resolution_insc: 12.2152 - energy_resolution_outsc: 9.9156 - val_loss: 442.4771 - val_precision: 0.9384 - val_recall: 0.8805 - val_energy_resolution_insc: 5.8036 - val_energy_resolution_outsc: 8.9138
# Epoch 53/100
# 769/769 [==============================] - 20s 26ms/step - loss: 549.1425 - precision: 0.9448 - recall: 0.8882 - energy_resolution_insc: 11.1474 - energy_resolution_outsc: 10.9504 - val_loss: 381.0939 - val_precision: 0.9294 - val_recall: 0.8997 - val_energy_resolution_insc: 4.4129 - val_energy_resolution_outsc: 5.5910
# Epoch 54/100
# 769/769 [==============================] - 22s 28ms/step - loss: 559.4735 - precision: 0.9457 - recall: 0.8870 - energy_resolution_insc: 11.9241 - energy_resolution_outsc: 10.7279 - val_loss: 472.5808 - val_precision: 0.9558 - val_recall: 0.8642 - val_energy_resolution_insc: 8.5499 - val_energy_resolution_outsc: 6.0703
# Epoch 55/100
# 769/769 [==============================] - 22s 28ms/step - loss: 550.2244 - precision: 0.9457 - recall: 0.8900 - energy_resolution_insc: 11.7921 - energy_resolution_outsc: 10.0760 - val_loss: 432.2699 - val_precision: 0.9430 - val_recall: 0.8724 - val_energy_resolution_insc: 6.5763 - val_energy_resolution_outsc: 6.1811
# Epoch 56/100
# 769/769 [==============================] - 19s 25ms/step - loss: 1240.1321 - precision: 0.9449 - recall: 0.8895 - energy_resolution_insc: 46.4671 - energy_resolution_outsc: 9.9096 - val_loss: 474.2886 - val_precision: 0.9338 - val_recall: 0.8751 - val_energy_resolution_insc: 8.2500 - val_energy_resolution_outsc: 6.3590
# Epoch 57/100
# 769/769 [==============================] - 22s 28ms/step - loss: 544.3847 - precision: 0.9451 - recall: 0.8904 - energy_resolution_insc: 11.9404 - energy_resolution_outsc: 9.5031 - val_loss: 531.0023 - val_precision: 0.9388 - val_recall: 0.8813 - val_energy_resolution_insc: 7.8080 - val_energy_resolution_outsc: 13.1682
# Epoch 58/100
# 769/769 [==============================] - 21s 27ms/step - loss: 628.0129 - precision: 0.9455 - recall: 0.8901 - energy_resolution_insc: 15.3912 - energy_resolution_outsc: 10.9469 - val_loss: 423.4816 - val_precision: 0.9301 - val_recall: 0.8906 - val_energy_resolution_insc: 5.0020 - val_energy_resolution_outsc: 8.5987
# Epoch 59/100
# 769/769 [==============================] - 19s 25ms/step - loss: 579.4059 - precision: 0.9467 - recall: 0.8881 - energy_resolution_insc: 13.2324 - energy_resolution_outsc: 10.3329 - val_loss: 508.4456 - val_precision: 0.9471 - val_recall: 0.8642 - val_energy_resolution_insc: 8.2394 - val_energy_resolution_outsc: 9.5397
# Epoch 60/100
# 769/769 [==============================] - 22s 28ms/step - loss: 545.7662 - precision: 0.9480 - recall: 0.8900 - energy_resolution_insc: 11.7936 - energy_resolution_outsc: 10.1179 - val_loss: 509.6872 - val_precision: 0.9294 - val_recall: 0.8891 - val_energy_resolution_insc: 7.5131 - val_energy_resolution_outsc: 10.9869
# Epoch 61/100
# 769/769 [==============================] - 21s 28ms/step - loss: 584.2726 - precision: 0.9447 - recall: 0.8848 - energy_resolution_insc: 13.2381 - energy_resolution_outsc: 9.7832 - val_loss: 467.5843 - val_precision: 0.9416 - val_recall: 0.8793 - val_energy_resolution_insc: 6.6913 - val_energy_resolution_outsc: 9.6984
# Epoch 62/100
# 769/769 [==============================] - 21s 28ms/step - loss: 539.8271 - precision: 0.9482 - recall: 0.8889 - energy_resolution_insc: 11.4725 - energy_resolution_outsc: 10.2983 - val_loss: 407.4600 - val_precision: 0.9214 - val_recall: 0.8945 - val_energy_resolution_insc: 5.2242 - val_energy_resolution_outsc: 6.1965
# Epoch 63/100
# 769/769 [==============================] - 21s 28ms/step - loss: 536.7743 - precision: 0.9457 - recall: 0.8926 - energy_resolution_insc: 11.3734 - energy_resolution_outsc: 10.2555 - val_loss: 472.7408 - val_precision: 0.9602 - val_recall: 0.8599 - val_energy_resolution_insc: 9.4819 - val_energy_resolution_outsc: 4.7353
# Epoch 64/100
# 769/769 [==============================] - 22s 28ms/step - loss: 530.7591 - precision: 0.9487 - recall: 0.8923 - energy_resolution_insc: 11.9169 - energy_resolution_outsc: 8.7320 - val_loss: 421.6946 - val_precision: 0.9444 - val_recall: 0.8836 - val_energy_resolution_insc: 7.4235 - val_energy_resolution_outsc: 4.6633
# Epoch 65/100
# 769/769 [==============================] - 19s 25ms/step - loss: 525.0116 - precision: 0.9476 - recall: 0.8935 - energy_resolution_insc: 10.7613 - energy_resolution_outsc: 10.5140 - val_loss: 516.7081 - val_precision: 0.9350 - val_recall: 0.8914 - val_energy_resolution_insc: 6.9085 - val_energy_resolution_outsc: 14.2885
# Epoch 66/100
# 769/769 [==============================] - 22s 28ms/step - loss: 579.7477 - precision: 0.9479 - recall: 0.8917 - energy_resolution_insc: 13.8612 - energy_resolution_outsc: 9.7195 - val_loss: 499.1343 - val_precision: 0.9514 - val_recall: 0.8614 - val_energy_resolution_insc: 9.3682 - val_energy_resolution_outsc: 6.8974
# Epoch 67/100
# 769/769 [==============================] - 21s 27ms/step - loss: 536.8853 - precision: 0.9486 - recall: 0.8937 - energy_resolution_insc: 11.4303 - energy_resolution_outsc: 10.5479 - val_loss: 489.2652 - val_precision: 0.9153 - val_recall: 0.8993 - val_energy_resolution_insc: 5.8256 - val_energy_resolution_outsc: 13.0067
# Epoch 68/100
# 769/769 [==============================] - 22s 28ms/step - loss: 575.8915 - precision: 0.9473 - recall: 0.8947 - energy_resolution_insc: 13.4959 - energy_resolution_outsc: 10.0886 - val_loss: 485.8470 - val_precision: 0.9543 - val_recall: 0.8669 - val_energy_resolution_insc: 7.2939 - val_energy_resolution_outsc: 9.4010
# Epoch 69/100
# 769/769 [==============================] - 22s 28ms/step - loss: 524.9837 - precision: 0.9489 - recall: 0.8947 - energy_resolution_insc: 11.8013 - energy_resolution_outsc: 8.6404 - val_loss: 472.9846 - val_precision: 0.9404 - val_recall: 0.8847 - val_energy_resolution_insc: 8.3410 - val_energy_resolution_outsc: 7.9325
# Epoch 70/100
# 769/769 [==============================] - 20s 27ms/step - loss: 568.6331 - precision: 0.9503 - recall: 0.8925 - energy_resolution_insc: 13.4207 - energy_resolution_outsc: 9.9745 - val_loss: 475.7438 - val_precision: 0.9384 - val_recall: 0.8833 - val_energy_resolution_insc: 7.0929 - val_energy_resolution_outsc: 9.5881
# Epoch 71/100
# 769/769 [==============================] - 22s 28ms/step - loss: 540.3808 - precision: 0.9510 - recall: 0.8926 - energy_resolution_insc: 11.9253 - energy_resolution_outsc: 9.8985 - val_loss: 430.7910 - val_precision: 0.9490 - val_recall: 0.8702 - val_energy_resolution_insc: 6.8623 - val_energy_resolution_outsc: 5.5267
# Epoch 72/100
# 769/769 [==============================] - 21s 27ms/step - loss: 534.5861 - precision: 0.9494 - recall: 0.8938 - energy_resolution_insc: 11.6067 - energy_resolution_outsc: 10.0125 - val_loss: 454.4187 - val_precision: 0.9634 - val_recall: 0.8562 - val_energy_resolution_insc: 6.7872 - val_energy_resolution_outsc: 8.0655
# Epoch 73/100
# 769/769 [==============================] - 20s 26ms/step - loss: 531.4348 - precision: 0.9507 - recall: 0.8946 - energy_resolution_insc: 11.1200 - energy_resolution_outsc: 10.9473 - val_loss: 471.6646 - val_precision: 0.9479 - val_recall: 0.8755 - val_energy_resolution_insc: 7.2150 - val_energy_resolution_outsc: 8.6292
# Epoch 74/100
# 769/769 [==============================] - 22s 28ms/step - loss: 529.1160 - precision: 0.9488 - recall: 0.8964 - energy_resolution_insc: 11.2903 - energy_resolution_outsc: 10.4007 - val_loss: 539.0286 - val_precision: 0.9468 - val_recall: 0.8750 - val_energy_resolution_insc: 11.4717 - val_energy_resolution_outsc: 7.6319
# Epoch 75/100
# 769/769 [==============================] - 21s 28ms/step - loss: 514.8396 - precision: 0.9487 - recall: 0.8950 - energy_resolution_insc: 10.7858 - energy_resolution_outsc: 9.7567 - val_loss: 435.2091 - val_precision: 0.9413 - val_recall: 0.8862 - val_energy_resolution_insc: 6.4754 - val_energy_resolution_outsc: 6.7092
# Epoch 76/100
# 769/769 [==============================] - 20s 25ms/step - loss: 569.8624 - precision: 0.9495 - recall: 0.8957 - energy_resolution_insc: 13.5677 - energy_resolution_outsc: 10.0150 - val_loss: 516.3279 - val_precision: 0.9439 - val_recall: 0.8801 - val_energy_resolution_insc: 6.6007 - val_energy_resolution_outsc: 15.1872
# Epoch 77/100
# 769/769 [==============================] - 22s 29ms/step - loss: 510.4757 - precision: 0.9513 - recall: 0.8962 - energy_resolution_insc: 10.6491 - energy_resolution_outsc: 9.9114 - val_loss: 467.6880 - val_precision: 0.9445 - val_recall: 0.8785 - val_energy_resolution_insc: 7.0067 - val_energy_resolution_outsc: 8.5579
# Epoch 78/100
# 769/769 [==============================] - 21s 28ms/step - loss: 671.5721 - precision: 0.9495 - recall: 0.8985 - energy_resolution_insc: 18.8920 - energy_resolution_outsc: 9.6715 - val_loss: 555.8682 - val_precision: 0.9663 - val_recall: 0.8513 - val_energy_resolution_insc: 10.6892 - val_energy_resolution_outsc: 9.4590
# Epoch 79/100
# 769/769 [==============================] - 19s 25ms/step - loss: 518.3747 - precision: 0.9507 - recall: 0.8967 - energy_resolution_insc: 11.2085 - energy_resolution_outsc: 9.7762 - val_loss: 471.3495 - val_precision: 0.9435 - val_recall: 0.8767 - val_energy_resolution_insc: 7.4270 - val_energy_resolution_outsc: 8.3276
# Epoch 80/100
# 769/769 [==============================] - 22s 29ms/step - loss: 549.7289 - precision: 0.9537 - recall: 0.8973 - energy_resolution_insc: 12.9872 - energy_resolution_outsc: 9.4940 - val_loss: 434.1693 - val_precision: 0.9169 - val_recall: 0.9048 - val_energy_resolution_insc: 4.6358 - val_energy_resolution_outsc: 8.7389
# Epoch 81/100
# 769/769 [==============================] - 21s 28ms/step - loss: 522.8240 - precision: 0.9509 - recall: 0.8975 - energy_resolution_insc: 11.1846 - energy_resolution_outsc: 10.1884 - val_loss: 436.1394 - val_precision: 0.9464 - val_recall: 0.8782 - val_energy_resolution_insc: 5.9238 - val_energy_resolution_outsc: 8.4993
# Epoch 82/100
# 769/769 [==============================] - 21s 28ms/step - loss: 522.1999 - precision: 0.9513 - recall: 0.8979 - energy_resolution_insc: 11.1356 - energy_resolution_outsc: 10.1561 - val_loss: 532.7132 - val_precision: 0.9745 - val_recall: 0.8326 - val_energy_resolution_insc: 11.8632 - val_energy_resolution_outsc: 4.6098
# Epoch 83/100
# 769/769 [==============================] - 26s 34ms/step - loss: 701.2176 - precision: 0.9526 - recall: 0.8959 - energy_resolution_insc: 20.3143 - energy_resolution_outsc: 9.7454 - val_loss: 415.3679 - val_precision: 0.9504 - val_recall: 0.8795 - val_energy_resolution_insc: 6.2014 - val_energy_resolution_outsc: 6.4564
# Epoch 84/100
# 769/769 [==============================] - 20s 26ms/step - loss: 619.6672 - precision: 0.9493 - recall: 0.8976 - energy_resolution_insc: 16.3059 - energy_resolution_outsc: 9.7328 - val_loss: 432.5579 - val_precision: 0.9449 - val_recall: 0.8807 - val_energy_resolution_insc: 5.9416 - val_energy_resolution_outsc: 7.8900
# Epoch 85/100
# 769/769 [==============================] - 22s 28ms/step - loss: 521.6039 - precision: 0.9529 - recall: 0.8971 - energy_resolution_insc: 11.4360 - energy_resolution_outsc: 9.7424 - val_loss: 469.0844 - val_precision: 0.9260 - val_recall: 0.8977 - val_energy_resolution_insc: 6.1956 - val_energy_resolution_outsc: 10.1558
# Epoch 86/100
# 769/769 [==============================] - 21s 27ms/step - loss: 575.6233 - precision: 0.9519 - recall: 0.8991 - energy_resolution_insc: 13.6037 - energy_resolution_outsc: 10.7971 - val_loss: 477.2209 - val_precision: 0.9518 - val_recall: 0.8679 - val_energy_resolution_insc: 8.1116 - val_energy_resolution_outsc: 6.4072
# Epoch 87/100
# 769/769 [==============================] - 20s 25ms/step - loss: 504.8646 - precision: 0.9532 - recall: 0.9002 - energy_resolution_insc: 10.7386 - energy_resolution_outsc: 9.8375 - val_loss: 508.8600 - val_precision: 0.9453 - val_recall: 0.8773 - val_energy_resolution_insc: 6.9697 - val_energy_resolution_outsc: 12.3539
# Epoch 88/100
# 769/769 [==============================] - 22s 28ms/step - loss: 514.8763 - precision: 0.9512 - recall: 0.9036 - energy_resolution_insc: 11.0833 - energy_resolution_outsc: 10.3378 - val_loss: 740.8868 - val_precision: 0.9494 - val_recall: 0.8724 - val_energy_resolution_insc: 21.1126 - val_energy_resolution_outsc: 8.2686
# Epoch 89/100
# 769/769 [==============================] - 21s 28ms/step - loss: 552.8902 - precision: 0.9542 - recall: 0.8996 - energy_resolution_insc: 12.9512 - energy_resolution_outsc: 10.2369 - val_loss: 498.8596 - val_precision: 0.9366 - val_recall: 0.8862 - val_energy_resolution_insc: 7.0098 - val_energy_resolution_outsc: 11.1724
# Epoch 90/100
# 769/769 [==============================] - 20s 25ms/step - loss: 993.7821 - precision: 0.9518 - recall: 0.9020 - energy_resolution_insc: 35.5642 - energy_resolution_outsc: 9.0669 - val_loss: 493.1161 - val_precision: 0.9289 - val_recall: 0.8943 - val_energy_resolution_insc: 8.6070 - val_energy_resolution_outsc: 7.8818
# Epoch 91/100
# 769/769 [==============================] - 26s 34ms/step - loss: 517.3804 - precision: 0.9540 - recall: 0.9017 - energy_resolution_insc: 11.5033 - energy_resolution_outsc: 10.0159 - val_loss: 523.8629 - val_precision: 0.9469 - val_recall: 0.8731 - val_energy_resolution_insc: 11.4701 - val_energy_resolution_outsc: 5.3289
# Epoch 92/100
# 769/769 [==============================] - 22s 28ms/step - loss: 527.4308 - precision: 0.9517 - recall: 0.9001 - energy_resolution_insc: 11.2715 - energy_resolution_outsc: 10.8222 - val_loss: 528.4787 - val_precision: 0.9587 - val_recall: 0.8503 - val_energy_resolution_insc: 10.0264 - val_energy_resolution_outsc: 7.5958
# Epoch 93/100
# 769/769 [==============================] - 22s 29ms/step - loss: 488.9300 - precision: 0.9520 - recall: 0.9033 - energy_resolution_insc: 10.2196 - energy_resolution_outsc: 9.6600 - val_loss: 439.5959 - val_precision: 0.9525 - val_recall: 0.8725 - val_energy_resolution_insc: 7.8590 - val_energy_resolution_outsc: 4.8830
# Epoch 94/100
# 769/769 [==============================] - 21s 28ms/step - loss: 639.6010 - precision: 0.9530 - recall: 0.9017 - energy_resolution_insc: 17.8243 - energy_resolution_outsc: 9.3833 - val_loss: 508.5119 - val_precision: 0.9183 - val_recall: 0.8955 - val_energy_resolution_insc: 6.7280 - val_energy_resolution_outsc: 11.7264
# Epoch 95/100
# 769/769 [==============================] - 22s 29ms/step - loss: 686.4394 - precision: 0.9540 - recall: 0.9015 - energy_resolution_insc: 20.4620 - energy_resolution_outsc: 8.9775 - val_loss: 508.7187 - val_precision: 0.9538 - val_recall: 0.8692 - val_energy_resolution_insc: 9.4398 - val_energy_resolution_outsc: 9.0548
# Epoch 96/100
# 769/769 [==============================] - 21s 28ms/step - loss: 519.6895 - precision: 0.9557 - recall: 0.9028 - energy_resolution_insc: 12.1729 - energy_resolution_outsc: 9.1623 - val_loss: 517.9985 - val_precision: 0.9646 - val_recall: 0.8471 - val_energy_resolution_insc: 8.9634 - val_energy_resolution_outsc: 8.9533
# Epoch 97/100
# 769/769 [==============================] - 22s 28ms/step - loss: 506.2502 - precision: 0.9534 - recall: 0.9033 - energy_resolution_insc: 11.3542 - energy_resolution_outsc: 9.3008 - val_loss: 502.1242 - val_precision: 0.9377 - val_recall: 0.8871 - val_energy_resolution_insc: 9.5099 - val_energy_resolution_outsc: 7.0485
# Epoch 98/100
# 769/769 [==============================] - 20s 26ms/step - loss: 528.8443 - precision: 0.9540 - recall: 0.9011 - energy_resolution_insc: 11.9019 - energy_resolution_outsc: 10.1047 - val_loss: 478.8427 - val_precision: 0.9593 - val_recall: 0.8663 - val_energy_resolution_insc: 8.1837 - val_energy_resolution_outsc: 8.2026
# Epoch 99/100
# 769/769 [==============================] - 22s 28ms/step - loss: 605.9960 - precision: 0.9549 - recall: 0.9032 - energy_resolution_insc: 16.6796 - energy_resolution_outsc: 8.8164 - val_loss: 446.5852 - val_precision: 0.9610 - val_recall: 0.8569 - val_energy_resolution_insc: 7.7826 - val_energy_resolution_outsc: 5.4358
# Epoch 100/100
# 769/769 [==============================] - 21s 28ms/step - loss: 512.1364 - precision: 0.9475 - recall: 0.9023 - energy_resolution_insc: 10.7447 - energy_resolution_outsc: 10.1662 - val_loss: 514.3119 - val_precision: 0.9575 - val_recall: 0.8650 - val_energy_resolution_insc: 8.4349 - val_energy_resolution_outsc: 11.0634

# %%
str(args)
# Out:
# "args(models_path='/storage/ECAL/deepcluster/models/gcn_models_v6/', load=False, nepochs=100, ntrain=50000, nval=10000, nfeatures=13, n_seed_features=12, batch_size=65, lr_decay=0, lr=0.0001, nhidden=128, distance_dim=100, num_conv=2, dropout=0.05, convlayer='ghconv', nclass_labels=2, opt='adam')"

# %%
with open(outdir + "/args.txt",'w') as config:
    config.write(str(args))
