# %%
import numpy as np
import matplotlib.colors as colors
import matplotlib.pyplot as plt

# %%
data_calo = np.load("data_calo.npy")
data_nocalo = np.load("data_nocalo.npy")

# %%
a = data_calo

# %%
plt.imshow(a[i,:,:,0], norm=colors.LogNorm(),cmap="Blues")
plt.colorbar()

# %%
for i in range(0, 100,2):
    f, ax = plt.subplots(1,5,figsize=(25,15))
    maxz = np.max(a[i,:,:,2])
    ax[0].imshow(a[i,:,:,0] , vmax=maxz,cmap="Blues")
    ax[1].imshow(a[i,:,:,1], vmax=maxz,cmap="Blues")
    ax[2].imshow(a[i,:,:,2] ,vmax=maxz,cmap="Blues")
    ax[3].imshow(a[i,:,:,3] ,vmax=maxz,cmap="Blues")
    im3 = ax[4].imshow(a[i,:,:,4] ,vmax=maxz,cmap="Blues")
# Out:
# /usr/local/bin/start_ipykernel.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   if __name__ == '__main__':

# %%
for i in range(0, 100,2):
    f, ax = plt.subplots(1,5,figsize=(25,15))
    maxz = np.max(a[i,:,:,2])
    ax[0].imshow(a[i,:,:,0] , vmax=maxz,cmap="Blues", norm=colors.LogNorm())
    ax[1].imshow(a[i,:,:,1], vmax=maxz,cmap="Blues", norm=colors.LogNorm())
    ax[2].imshow(a[i,:,:,2] ,vmax=maxz,cmap="Blues", norm=colors.LogNorm())
    ax[3].imshow(a[i,:,:,3] ,vmax=maxz,cmap="Blues", norm=colors.LogNorm())
    im3 = ax[4].imshow(a[i,:,:,4] ,vmax=maxz,cmap="Blues", norm=colors.LogNorm())
# Out:
# /usr/local/bin/start_ipykernel.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   if __name__ == '__main__':
