# %%
import pickle
from pandarallel import pandarallel
pandarallel.initialize(use_memory_fs=False)
import numpy as np 
import pandas as pd
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import make_axes_locatable
import argparse
import os 
import glob
from collections import namedtuple, defaultdict

import os
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# INFO: Pandarallel will run on 10 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
model_name = "v16_elegammasep"
model_dir = "../models/"+model_name

model_version = 1
numpy_version = 1
files_ele = f"/storage/ECAL/training_data/wp_comparison/electrons/numpy_wp_ele_v1/training/"
limit_files = 20

cols = ["seed_eta", "seed_iz","en_seed","et_seed",
        "cluster_deta", "cluster_dphi", "en_cluster", "et_cluster",
       "seed_f5_r9", "seed_f5_sigmaIetaIeta","seed_f5_sigmaIetaIphi","seed_f5_sigmaIphiIphi",
        "seed_f5_swissCross","seed_nxtals", "seed_etaWidth", "seed_phiWidth",
        "cl_f5_r9", "cl_f5_sigmaIetaIeta","cl_f5_sigmaIetaIphi","cl_f5_sigmaIphiIphi",
        "cl_f5_swissCross", "cl_nxtals", "cl_etaWidth", "cl_phiWidth"]

# %%
from keras.models  import load_model

model_EB = load_model(model_dir + f"/model_v{model_version}_EB_ele.hd5")
model_EE = load_model(model_dir + f"/model_v{model_version}_EE_ele.hd5")
scaler_EB = pickle.load(open(model_dir + f"/scaler_model_v{model_version}_EB_ele.pkl", "rb"))
scaler_EE = pickle.load(open(model_dir + f"/scaler_model_v{model_version}_EE_ele.pkl", "rb"))
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Including only clusters where the seed is calomatched

# %%
datas_ele = []

i = 0
for f in glob.glob(files_ele+"*.pkl"):
    if i>limit_files :continue
    d = pickle.load(open(f, "rb"))   
    datas_ele.append( d[(d.is_seed_calo_matched == True)] )
    i+=1
    
data = pd.concat(datas_ele, ignore_index=True)
print("N events ele: ",len(data))
# Out:
# N events ele:  6396025

# %%
print('EB')
data.loc[data.seed_iz==0, "y"] = model_EB.predict(scaler_EB.transform(data[data.seed_iz==0][cols].values), batch_size=4096)
print('EE')
data.loc[data.seed_iz!=0, "y"] = model_EE.predict(scaler_EE.transform(data[data.seed_iz!=0][cols].values), batch_size=4096)
# Out:
# EB
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-53ed769bfb2d> in <module>
#       1 print('EB')
# ----> 2 data.loc[data.seed_iz==0, "y"] = model_EB.predict(scaler_EB.transform(data[data.seed_iz==0][cols].values), batch_size=4096)
#       3 print('EE')
#       4 data.loc[data.seed_iz!=0, "y"] = model_EE.predict(scaler_EE.transform(data[data.seed_iz!=0][cols].values), batch_size=4096)
#
# NameError: name 'model_EB' is not defined

# %%
data.columns
# Out:
# Index(['calo_seed_index', 'cl_etaWidth', 'cl_f5_r9', 'cl_f5_sigmaIetaIeta',
#        'cl_f5_sigmaIetaIphi', 'cl_f5_sigmaIphiIphi', 'cl_f5_swissCross',
#        'cl_nxtals', 'cl_phiWidth', 'cluster_deta', 'cluster_dphi',
#        'cluster_iz', 'en_cluster', 'en_cluster_calib', 'en_seed',
#        'en_seed_calib', 'en_true', 'et_cluster', 'et_cluster_calib', 'et_seed',
#        'et_seed_calib', 'et_true', 'in_geom_mustache', 'in_mustache',
#        'in_scluster', 'is_calo_matched', 'is_seed', 'is_seed_calo_matched',
#        'is_seed_mustached_matched', 'mustache_seed_index', 'seed_eta',
#        'seed_etaWidth', 'seed_f5_r9', 'seed_f5_sigmaIetaIeta',
#        'seed_f5_sigmaIetaIphi', 'seed_f5_sigmaIphiIphi', 'seed_f5_swissCross',
#        'seed_iz', 'seed_nxtals', 'seed_phi', 'seed_phiWidth', 'window_index'],
#       dtype='object')

# %%
data.window_index.unique().shape
# Out:
# (804139,)

# %%
data_must = data[data.is_seed_mustached_matched]

# %%
from multiprocessing import Pool

def analyze(group):
    grid,g = group
    
    data_calo = defaultdict(list)
    true_en = g.en_true.values[0]
    in_sc_true = np.cast['int32'](g.in_scluster.values)
    
    #do not count seeds for the ncls metrics
    nclusters = len(g) -1
    
    
    mask = np.cast['int32']((g.in_mustache))
    mask_withseed = np.cast['int32']((g.in_mustache)| (g.is_seed))

    pred_en =  np.sum(g.en_cluster.values * mask_withseed, axis=-1)

    tp =  np.cast['int32']((in_sc_true * mask_withseed) ==1)
    fp =  np.cast['int32']((in_sc_true - mask_withseed) <0)
    fn =  np.cast['int32']((in_sc_true - mask_withseed) >0)

    E_tp = np.sum(g.en_cluster.values * tp, axis=-1)
    E_fp = np.sum(g.en_cluster.values * fp, axis=-1)
    E_fn = np.sum(g.en_cluster.values * fn, axis=-1)

    data_calo['seed_eta'].append(g.seed_eta.values[0])
    data_calo['seed_en'].append(g.en_seed.values[0])
    data_calo['seed_et'].append(g.et_seed.values[0])
    data_calo['ncls'].append(nclusters)
    data_calo['ncls_sel'].append(np.sum(mask_withseed, axis=-1) - 1)
    data_calo['ncls_true'].append(np.sum(in_sc_true,axis=-1)-1)
    data_calo['ncls_sel_true'].append(np.sum(tp,axis=-1) -1 )
    data_calo['seed_sel'].append( int(mask[g.is_seed.values][0]==1) )
    data_calo['EoEtrue'].append( pred_en / true_en)
    data_calo['Etrue'].append(true_en)
    data_calo['Epred'].append(pred_en)
    data_calo['E_tp'].append(E_tp)
    data_calo['E_fp'].append(E_fp)
    data_calo['E_fn'].append(E_fn)
    return(data_calo)

pool = Pool(6)
data_calos = pool.map(analyze, data_must.groupby('window_index', sort=False))

# %%
data_calos
# Out:
# [defaultdict(list,
#              {'seed_eta': [-1.5677804946899414],
#               'seed_en': [214.77279663085938],
#               'seed_et': [85.831885479732],
#               'ncls': [2],
#               'ncls_sel': [1],
#               'ncls_true': [1],
#               'ncls_sel_true': [1],
#               'seed_sel': [1],
#               'EoEtrue': [0.9953103816454467],
#               'Etrue': [218.35621643066406],
#               'Epred': [217.33220911026],
#               'E_tp': [217.33220911026],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [0.9756220579147339],
#               'seed_en': [51.86598587036133],
#               'seed_et': [34.23752001264564],
#               'ncls': [7],
#               'ncls_sel': [1],
#               'ncls_true': [2],
#               'ncls_sel_true': [1],
#               'seed_sel': [1],
#               'EoEtrue': [0.9381612844559252],
#               'Etrue': [62.82096862792969],
#               'Epred': [58.9362006187439],
#               'E_tp': [58.9362006187439],
#               'E_fp': [0.0],
#               'E_fn': [0.7998005151748657]}),
#  defaultdict(list,
#              {'seed_eta': [-0.6782552599906921],
#               'seed_en': [20.75385856628418],
#               'seed_et': [16.750906836887108],
#               'ncls': [6],
#               'ncls_sel': [3],
#               'ncls_true': [2],
#               'ncls_sel_true': [2],
#               'seed_sel': [1],
#               'EoEtrue': [0.9500069800726091],
#               'Etrue': [34.94264602661133],
#               'Epred': [33.19575762748718],
#               'E_tp': [32.724992752075195],
#               'E_fp': [0.4707648754119873],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-2.761141300201416],
#               'seed_en': [430.2557373046875],
#               'seed_et': [54.18460899320749],
#               'ncls': [0],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9871820420031758],
#               'Etrue': [435.84234619140625],
#               'Epred': [430.2557373046875],
#               'E_tp': [430.2557373046875],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-0.7242050170898438],
#               'seed_en': [60.28792190551758],
#               'seed_et': [47.32547300206978],
#               'ncls': [3],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9704710993156583],
#               'Etrue': [62.1223258972168],
#               'Epred': [60.28792190551758],
#               'E_tp': [60.28792190551758],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [2.820347785949707],
#               'seed_en': [158.51783752441406],
#               'seed_et': [18.823807234777394],
#               'ncls': [0],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.7997146357525914],
#               'Etrue': [198.21800231933594],
#               'Epred': [158.51783752441406],
#               'E_tp': [158.51783752441406],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [0.9978808760643005],
#               'seed_en': [13.204082489013672],
#               'seed_et': [8.570775333462622],
#               'ncls': [8],
#               'ncls_sel': [2],
#               'ncls_true': [1],
#               'ncls_sel_true': [1],
#               'seed_sel': [1],
#               'EoEtrue': [0.9588006214230405],
#               'Etrue': [26.612266540527344],
#               'Epred': [25.515857696533203],
#               'E_tp': [25.00545597076416],
#               'E_fp': [0.510401725769043],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [1.1745989322662354],
#               'seed_en': [148.49298095703125],
#               'seed_et': [83.7574091387821],
#               'ncls': [7],
#               'ncls_sel': [2],
#               'ncls_true': [2],
#               'ncls_sel_true': [2],
#               'seed_sel': [1],
#               'EoEtrue': [0.9750902412974972],
#               'Etrue': [158.95611572265625],
#               'Epred': [154.99655723571777],
#               'E_tp': [154.99655723571777],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [2.167304277420044],
#               'seed_en': [218.64076232910156],
#               'seed_et': [49.41485468941564],
#               'ncls': [3],
#               'ncls_sel': [1],
#               'ncls_true': [1],
#               'ncls_sel_true': [1],
#               'seed_sel': [1],
#               'EoEtrue': [1.0005274966097968],
#               'Etrue': [228.58680725097656],
#               'Epred': [228.7073860168457],
#               'E_tp': [228.7073860168457],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-2.5663936138153076],
#               'seed_en': [177.6587677001953],
#               'seed_et': [27.13258723639885],
#               'ncls': [2],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.8793355140286438],
#               'Etrue': [202.0375213623047],
#               'Epred': [177.6587677001953],
#               'E_tp': [177.6587677001953],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-0.9423127770423889],
#               'seed_en': [29.98993492126465],
#               'seed_et': [20.29339969632492],
#               'ncls': [6],
#               'ncls_sel': [2],
#               'ncls_true': [1],
#               'ncls_sel_true': [1],
#               'seed_sel': [1],
#               'EoEtrue': [1.0015797564650981],
#               'Etrue': [47.0855712890625],
#               'Epred': [47.15995502471924],
#               'E_tp': [46.26354789733887],
#               'E_fp': [0.8964071273803711],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [1.0943740606307983],
#               'seed_en': [80.1241455078125],
#               'seed_et': [48.237608144439776],
#               'ncls': [16],
#               'ncls_sel': [4],
#               'ncls_true': [3],
#               'ncls_sel_true': [3],
#               'seed_sel': [1],
#               'EoEtrue': [0.978226865866475],
#               'Etrue': [88.44290924072266],
#               'Epred': [86.51722991466522],
#               'E_tp': [85.36769616603851],
#               'E_fp': [1.149533748626709],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-2.2104382514953613],
#               'seed_en': [117.33879852294922],
#               'seed_et': [25.427274946049742],
#               'ncls': [3],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9565598272550897],
#               'Etrue': [122.66749572753906],
#               'Epred': [117.33879852294922],
#               'E_tp': [117.33879852294922],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [2.491276264190674],
#               'seed_en': [152.8594207763672],
#               'seed_et': [25.142419948154387],
#               'ncls': [3],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9123034256884148],
#               'Etrue': [167.5532684326172],
#               'Epred': [152.8594207763672],
#               'E_tp': [152.8594207763672],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-0.7133630514144897],
#               'seed_en': [18.381683349609375],
#               'seed_et': [14.526170773469943],
#               'ncls': [4],
#               'ncls_sel': [1],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9429435944581632],
#               'Etrue': [19.82365608215332],
#               'Epred': [18.69258952140808],
#               'E_tp': [18.381683349609375],
#               'E_fp': [0.31090617179870605],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [0.6372336745262146],
#               'seed_en': [67.50000762939453],
#               'seed_et': [55.78524664550476],
#               'ncls': [8],
#               'ncls_sel': [2],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [1.0319669643306593],
#               'Etrue': [66.08114624023438],
#               'Epred': [68.19355988502502],
#               'E_tp': [67.50000762939453],
#               'E_fp': [0.6935522556304932],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [2.160266637802124],
#               'seed_en': [187.2112274169922],
#               'seed_et': [42.60249678559931],
#               'ncls': [7],
#               'ncls_sel': [1],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [1.0297187305351345],
#               'Etrue': [183.31349182128906],
#               'Epred': [188.76133608818054],
#               'E_tp': [187.2112274169922],
#               'E_fp': [1.5501086711883545],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-1.113903284072876],
#               'seed_en': [27.4345760345459],
#               'seed_et': [16.25993248581422],
#               'ncls': [13],
#               'ncls_sel': [3],
#               'ncls_true': [2],
#               'ncls_sel_true': [2],
#               'seed_sel': [1],
#               'EoEtrue': [0.9494132883742731],
#               'Etrue': [59.053104400634766],
#               'Epred': [56.06580203771591],
#               'E_tp': [55.303419172763824],
#               'E_fp': [0.7623828649520874],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-1.7149502038955688],
#               'seed_en': [18.765827178955078],
#               'seed_et': [6.542751694537206],
#               'ncls': [8],
#               'ncls_sel': [2],
#               'ncls_true': [1],
#               'ncls_sel_true': [1],
#               'seed_sel': [1],
#               'EoEtrue': [0.8773397671230143],
#               'Etrue': [34.21723556518555],
#               'Epred': [30.02014148235321],
#               'E_tp': [29.27059841156006],
#               'E_fp': [0.7495430707931519],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-0.8079812526702881],
#               'seed_en': [89.09957122802734],
#               'seed_et': [66.26642598092994],
#               'ncls': [11],
#               'ncls_sel': [1],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [1.000696301866612],
#               'Etrue': [89.62090301513672],
#               'Epred': [89.6833062171936],
#               'E_tp': [89.09957122802734],
#               'E_fp': [0.5837349891662598],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-1.5700769424438477],
#               'seed_en': [128.9898223876953],
#               'seed_et': [51.441119798808515],
#               'ncls': [3],
#               'ncls_sel': [2],
#               'ncls_true': [3],
#               'ncls_sel_true': [2],
#               'seed_sel': [1],
#               'EoEtrue': [0.9175646246351282],
#               'Etrue': [155.6107177734375],
#               'Epred': [142.78288984298706],
#               'E_tp': [142.78288984298706],
#               'E_fp': [0.0],
#               'E_fn': [1.0692352056503296]}),
#  defaultdict(list,
#              {'seed_eta': [1.2337685823440552],
#               'seed_en': [66.3052749633789],
#               'seed_et': [35.596896907364716],
#               'ncls': [17],
#               'ncls_sel': [8],
#               'ncls_true': [2],
#               'ncls_sel_true': [2],
#               'seed_sel': [1],
#               'EoEtrue': [1.0123193904561525],
#               'Etrue': [73.24079895019531],
#               'Epred': [74.14308094978333],
#               'E_tp': [71.63345539569855],
#               'E_fp': [2.509625554084778],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [0.133238285779953],
#               'seed_en': [72.24431610107422],
#               'seed_et': [71.60776890839028],
#               'ncls': [13],
#               'ncls_sel': [1],
#               'ncls_true': [1],
#               'ncls_sel_true': [1],
#               'seed_sel': [1],
#               'EoEtrue': [0.9823153534975565],
#               'Etrue': [74.93994903564453],
#               'Epred': [73.61466252803802],
#               'E_tp': [73.61466252803802],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-0.16090013086795807],
#               'seed_en': [66.53687286376953],
#               'seed_et': [65.68478509928912],
#               'ncls': [7],
#               'ncls_sel': [1],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [1.0082463636709917],
#               'Etrue': [66.23473358154297],
#               'Epred': [66.78092928230762],
#               'E_tp': [66.53687286376953],
#               'E_fp': [0.24405641853809357],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-1.6784989833831787],
#               'seed_en': [149.9230194091797],
#               'seed_et': [54.08320141863605],
#               'ncls': [11],
#               'ncls_sel': [3],
#               'ncls_true': [3],
#               'ncls_sel_true': [1],
#               'seed_sel': [1],
#               'EoEtrue': [0.9789562749757723],
#               'Etrue': [161.52967834472656],
#               'Epred': [158.13049221038818],
#               'E_tp': [155.84620475769043],
#               'E_fp': [2.284287452697754],
#               'E_fn': [6.006664991378784]}),
#  defaultdict(list,
#              {'seed_eta': [1.9813750982284546],
#               'seed_en': [129.6626434326172],
#               'seed_et': [35.08858264208915],
#               'ncls': [10],
#               'ncls_sel': [1],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [1.0082288187163997],
#               'Etrue': [132.51937866210938],
#               'Epred': [133.60985660552979],
#               'E_tp': [129.6626434326172],
#               'E_fp': [3.9472131729125977],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [1.047601342201233],
#               'seed_en': [35.13393783569336],
#               'seed_et': [21.947854211131123],
#               'ncls': [6],
#               'ncls_sel': [1],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9583019355326576],
#               'Etrue': [36.939117431640625],
#               'Epred': [35.398827731609344],
#               'E_tp': [35.13393783569336],
#               'E_fp': [0.2648898959159851],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-2.6899826526641846],
#               'seed_en': [146.6634521484375],
#               'seed_et': [19.820319546055792],
#               'ncls': [1],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9980422798603201],
#               'Etrue': [146.95114135742188],
#               'Epred': [146.6634521484375],
#               'E_tp': [146.6634521484375],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-0.176580548286438],
#               'seed_en': [90.43903350830078],
#               'seed_et': [89.04714673367931],
#               'ncls': [5],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [1.0171681733949731],
#               'Etrue': [88.91256713867188],
#               'Epred': [90.43903350830078],
#               'E_tp': [90.43903350830078],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [0.37446898221969604],
#               'seed_en': [75.6775894165039],
#               'seed_et': [70.664859856814],
#               'ncls': [13],
#               'ncls_sel': [1],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9655930430569721],
#               'Etrue': [78.62494659423828],
#               'Epred': [75.91970144212246],
#               'E_tp': [75.6775894165039],
#               'E_fp': [0.24211202561855316],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [1.5384657382965088],
#               'seed_en': [151.94496154785156],
#               'seed_et': [62.37286723361726],
#               'ncls': [6],
#               'ncls_sel': [6],
#               'ncls_true': [6],
#               'ncls_sel_true': [6],
#               'seed_sel': [1],
#               'EoEtrue': [0.9699162011071819],
#               'Etrue': [169.5066680908203],
#               'Epred': [164.4072635769844],
#               'E_tp': [164.4072635769844],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-1.7252449989318848],
#               'seed_en': [95.06147766113281],
#               'seed_et': [32.82495042801558],
#               'ncls': [3],
#               'ncls_sel': [2],
#               'ncls_true': [2],
#               'ncls_sel_true': [2],
#               'seed_sel': [1],
#               'EoEtrue': [0.891007630156687],
#               'Etrue': [115.47871398925781],
#               'Epred': [102.89241528511047],
#               'E_tp': [102.89241528511047],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [1.7781367301940918],
#               'seed_en': [266.574462890625],
#               'seed_et': [87.57704168866053],
#               'ncls': [7],
#               'ncls_sel': [2],
#               'ncls_true': [1],
#               'ncls_sel_true': [1],
#               'seed_sel': [1],
#               'EoEtrue': [0.991168720366064],
#               'Etrue': [270.9195251464844],
#               'Epred': [268.5269590616226],
#               'E_tp': [267.7806124687195],
#               'E_fp': [0.7463465929031372],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [0.6772010922431946],
#               'seed_en': [41.556907653808594],
#               'seed_et': [33.56238581880821],
#               'ncls': [11],
#               'ncls_sel': [4],
#               'ncls_true': [3],
#               'ncls_sel_true': [3],
#               'seed_sel': [1],
#               'EoEtrue': [0.9921424954635746],
#               'Etrue': [52.34415817260742],
#               'Epred': [51.93286371231079],
#               'E_tp': [51.695812702178955],
#               'E_fp': [0.23705101013183594],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-1.3230739831924438],
#               'seed_en': [35.822452545166016],
#               'seed_et': [17.816523921966517],
#               'ncls': [19],
#               'ncls_sel': [10],
#               'ncls_true': [8],
#               'ncls_sel_true': [8],
#               'seed_sel': [1],
#               'EoEtrue': [0.9349646615501065],
#               'Etrue': [95.1376724243164],
#               'Epred': [88.95036169886589],
#               'E_tp': [87.59605965018272],
#               'E_fp': [1.3543020486831665],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-2.0040225982666016],
#               'seed_en': [6.338052749633789],
#               'seed_et': [1.6781472724066995],
#               'ncls': [5],
#               'ncls_sel': [2],
#               'ncls_true': [2],
#               'ncls_sel_true': [1],
#               'seed_sel': [1],
#               'EoEtrue': [0.41316984297012843],
#               'Etrue': [21.396623611450195],
#               'Epred': [8.84043961763382],
#               'E_tp': [7.84486997127533],
#               'E_fp': [0.99556964635849],
#               'E_fn': [1.2510250806808472]}),
#  defaultdict(list,
#              {'seed_eta': [2.8259260654449463],
#               'seed_en': [558.144775390625],
#               'seed_et': [65.91293069929854],
#               'ncls': [1],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9891092078565478],
#               'Etrue': [564.2903442382812],
#               'Epred': [558.144775390625],
#               'E_tp': [558.144775390625],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-2.647054433822632],
#               'seed_en': [87.15291595458984],
#               'seed_et': [12.289539507003058],
#               'ncls': [1],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [1.0370091473677217],
#               'Etrue': [84.04257202148438],
#               'Epred': [87.15291595458984],
#               'E_tp': [87.15291595458984],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [0.6241775155067444],
#               'seed_en': [6.015501499176025],
#               'seed_et': [5.00788532574167],
#               'ncls': [9],
#               'ncls_sel': [2],
#               'ncls_true': [2],
#               'ncls_sel_true': [2],
#               'seed_sel': [1],
#               'EoEtrue': [0.8427996507226443],
#               'Etrue': [11.183805465698242],
#               'Epred': [9.425707340240479],
#               'E_tp': [9.425707340240479],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-0.5411390066146851],
#               'seed_en': [4.300722122192383],
#               'seed_et': [3.7396813052675166],
#               'ncls': [7],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.07261514911660286],
#               'Etrue': [59.22623825073242],
#               'Epred': [4.300722122192383],
#               'E_tp': [4.300722122192383],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-1.2761778831481934],
#               'seed_en': [166.97840881347656],
#               'seed_et': [86.47203094157913],
#               'ncls': [9],
#               'ncls_sel': [2],
#               'ncls_true': [2],
#               'ncls_sel_true': [2],
#               'seed_sel': [1],
#               'EoEtrue': [1.0021211776297376],
#               'Etrue': [171.1968994140625],
#               'Epred': [171.56003844738007],
#               'E_tp': [171.56003844738007],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [2.387582778930664],
#               'seed_en': [435.4686279296875],
#               'seed_et': [79.32757998292614],
#               'ncls': [4],
#               'ncls_sel': [1],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9564235225848569],
#               'Etrue': [458.082763671875],
#               'Epred': [438.1211304664612],
#               'E_tp': [435.4686279296875],
#               'E_fp': [2.6525025367736816],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [1.0905557870864868],
#               'seed_en': [121.06322479248047],
#               'seed_et': [73.10675513256496],
#               'ncls': [20],
#               'ncls_sel': [5],
#               'ncls_true': [6],
#               'ncls_sel_true': [5],
#               'seed_sel': [1],
#               'EoEtrue': [0.9755195093467458],
#               'Etrue': [140.98622131347656],
#               'Epred': [137.53480944037437],
#               'E_tp': [137.53480944037437],
#               'E_fp': [0.0],
#               'E_fn': [1.2067182064056396]}),
#  defaultdict(list,
#              {'seed_eta': [-2.059750556945801],
#               'seed_en': [30.484416961669922],
#               'seed_et': [7.648352741744531],
#               'ncls': [8],
#               'ncls_sel': [1],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [1.0054247859434688],
#               'Etrue': [34.23588562011719],
#               'Epred': [34.421607971191406],
#               'E_tp': [30.484416961669922],
#               'E_fp': [3.9371910095214844],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [0.818321704864502],
#               'seed_en': [84.35459899902344],
#               'seed_et': [62.30342563649917],
#               'ncls': [8],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [1.0097845624473545],
#               'Etrue': [83.53722381591797],
#               'Epred': [84.35459899902344],
#               'E_tp': [84.35459899902344],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [2.1234819889068604],
#               'seed_en': [185.987548828125],
#               'seed_et': [43.86596360966915],
#               'ncls': [6],
#               'ncls_sel': [1],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9803551758640315],
#               'Etrue': [190.60826110839844],
#               'Epred': [186.8637953400612],
#               'E_tp': [185.987548828125],
#               'E_fp': [0.8762465119361877],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-0.06949117034673691],
#               'seed_en': [21.922168731689453],
#               'seed_et': [21.86934369985335],
#               'ncls': [2],
#               'ncls_sel': [1],
#               'ncls_true': [1],
#               'ncls_sel_true': [1],
#               'seed_sel': [1],
#               'EoEtrue': [0.9775085283908067],
#               'Etrue': [36.9364128112793],
#               'Epred': [36.105658531188965],
#               'E_tp': [36.105658531188965],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-1.95052170753479],
#               'seed_en': [31.29083251953125],
#               'seed_et': [8.722723880428218],
#               'ncls': [5],
#               'ncls_sel': [2],
#               'ncls_true': [4],
#               'ncls_sel_true': [2],
#               'seed_sel': [1],
#               'EoEtrue': [0.8040620430929257],
#               'Etrue': [57.11990737915039],
#               'Epred': [45.92794942855835],
#               'E_tp': [45.92794942855835],
#               'E_fp': [0.0],
#               'E_fn': [2.2801249027252197]}),
#  defaultdict(list,
#              {'seed_eta': [0.6201112270355225],
#               'seed_en': [100.56388092041016],
#               'seed_et': [83.9074393310755],
#               'ncls': [20],
#               'ncls_sel': [2],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [1.001667983868196],
#               'Etrue': [101.17045593261719],
#               'Epred': [101.33920662105083],
#               'E_tp': [100.56388092041016],
#               'E_fp': [0.7753257006406784],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [1.9782642126083374],
#               'seed_en': [282.96380615234375],
#               'seed_et': [76.80373120503502],
#               'ncls': [7],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9975116424579852],
#               'Etrue': [283.669677734375],
#               'Epred': [282.96380615234375],
#               'E_tp': [282.96380615234375],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-0.15913410484790802],
#               'seed_en': [62.79130935668945],
#               'seed_et': [62.00455987574081],
#               'ncls': [12],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9860787459273485],
#               'Etrue': [63.67778396606445],
#               'Epred': [62.79130935668945],
#               'E_tp': [62.79130935668945],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-2.2996561527252197],
#               'seed_en': [69.74659729003906],
#               'seed_et': [13.850913190447628],
#               'ncls': [5],
#               'ncls_sel': [2],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9710465538293308],
#               'Etrue': [75.92454528808594],
#               'Epred': [73.72626805305481],
#               'E_tp': [69.74659729003906],
#               'E_fp': [3.979670763015747],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-0.9978576898574829],
#               'seed_en': [92.13164520263672],
#               'seed_et': [59.80374329978304],
#               'ncls': [7],
#               'ncls_sel': [2],
#               'ncls_true': [1],
#               'ncls_sel_true': [1],
#               'seed_sel': [1],
#               'EoEtrue': [0.9964224432045767],
#               'Etrue': [101.4267349243164],
#               'Epred': [101.06387501955032],
#               'E_tp': [100.73126792907715],
#               'E_fp': [0.33260709047317505],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [2.828000783920288],
#               'seed_en': [214.9045867919922],
#               'seed_et': [25.326472003343092],
#               'ncls': [0],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.8949588997816041],
#               'Etrue': [240.1278839111328],
#               'Epred': [214.9045867919922],
#               'E_tp': [214.9045867919922],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [0.20265023410320282],
#               'seed_en': [24.291019439697266],
#               'seed_et': [23.800632956458333],
#               'ncls': [5],
#               'ncls_sel': [1],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9943589549915416],
#               'Etrue': [24.664756774902344],
#               'Epred': [24.52562177181244],
#               'E_tp': [24.291019439697266],
#               'E_fp': [0.23460233211517334],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-2.347404718399048],
#               'seed_en': [18.751426696777344],
#               'seed_et': [3.553422534893126],
#               'ncls': [4],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.604985383586097],
#               'Etrue': [30.994842529296875],
#               'Epred': [18.751426696777344],
#               'E_tp': [18.751426696777344],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-0.22248207032680511],
#               'seed_en': [83.37835693359375],
#               'seed_et': [81.35653389806774],
#               'ncls': [6],
#               'ncls_sel': [1],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [1.0049352256852242],
#               'Etrue': [83.33609771728516],
#               'Epred': [83.74738016724586],
#               'E_tp': [83.37835693359375],
#               'E_fp': [0.36902323365211487],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-1.5503489971160889],
#               'seed_en': [189.0408935546875],
#               'seed_et': [76.76337617898545],
#               'ncls': [4],
#               'ncls_sel': [2],
#               'ncls_true': [1],
#               'ncls_sel_true': [1],
#               'seed_sel': [1],
#               'EoEtrue': [1.0049493261246478],
#               'Etrue': [190.91534423828125],
#               'Epred': [191.8602465391159],
#               'E_tp': [191.09186911582947],
#               'E_fp': [0.768377423286438],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [2.7092058658599854],
#               'seed_en': [561.836669921875],
#               'seed_et': [74.49471011791347],
#               'ncls': [1],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [1.0239462042730592],
#               'Etrue': [548.6974487304688],
#               'Epred': [561.836669921875],
#               'E_tp': [561.836669921875],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [0.8615333437919617],
#               'seed_en': [33.91884994506836],
#               'seed_et': [24.320683308602902],
#               'ncls': [16],
#               'ncls_sel': [1],
#               'ncls_true': [1],
#               'ncls_sel_true': [1],
#               'seed_sel': [1],
#               'EoEtrue': [0.9840508683575488],
#               'Etrue': [51.99404525756836],
#               'Epred': [51.164785385131836],
#               'E_tp': [51.164785385131836],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-1.0461300611495972],
#               'seed_en': [89.80452728271484],
#               'seed_et': [56.164544231799844],
#               'ncls': [9],
#               'ncls_sel': [2],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9988983123709161],
#               'Etrue': [90.42938232421875],
#               'Epred': [90.32975739240646],
#               'E_tp': [89.80452728271484],
#               'E_fp': [0.5252301096916199],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-1.658955693244934],
#               'seed_en': [83.62313079833984],
#               'seed_et': [30.720311592347286],
#               'ncls': [4],
#               'ncls_sel': [2],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9670172075585955],
#               'Etrue': [88.70243835449219],
#               'Epred': [85.7767842411995],
#               'E_tp': [83.62313079833984],
#               'E_fp': [2.1536534428596497],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [2.851480484008789],
#               'seed_en': [255.6932830810547],
#               'seed_et': [29.438837008314245],
#               'ncls': [0],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9118506027085973],
#               'Etrue': [280.411376953125],
#               'Epred': [255.6932830810547],
#               'E_tp': [255.6932830810547],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [0.7755369544029236],
#               'seed_en': [8.770856857299805],
#               'seed_et': [6.664241934007843],
#               'ncls': [10],
#               'ncls_sel': [5],
#               'ncls_true': [3],
#               'ncls_sel_true': [3],
#               'seed_sel': [1],
#               'EoEtrue': [0.9408388797309377],
#               'Etrue': [14.100621223449707],
#               'Epred': [13.266412675380707],
#               'E_tp': [12.307575523853302],
#               'E_fp': [0.9588371515274048],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-0.386989027261734],
#               'seed_en': [39.92008972167969],
#               'seed_et': [37.10668188392862],
#               'ncls': [11],
#               'ncls_sel': [1],
#               'ncls_true': [1],
#               'ncls_sel_true': [1],
#               'seed_sel': [1],
#               'EoEtrue': [0.9824834338436523],
#               'Etrue': [45.28902816772461],
#               'Epred': [44.49571990966797],
#               'E_tp': [44.49571990966797],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [2.2960398197174072],
#               'seed_en': [160.11099243164062],
#               'seed_et': [31.909183568371837],
#               'ncls': [4],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9977414204547453],
#               'Etrue': [160.4734344482422],
#               'Epred': [160.11099243164062],
#               'E_tp': [160.11099243164062],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [1.0030516386032104],
#               'seed_en': [29.801549911499023],
#               'seed_et': [19.268150690935833],
#               'ncls': [17],
#               'ncls_sel': [5],
#               'ncls_true': [3],
#               'ncls_sel_true': [2],
#               'seed_sel': [1],
#               'EoEtrue': [0.9342553483020211],
#               'Etrue': [41.498939514160156],
#               'Epred': [38.7706061899662],
#               'E_tp': [37.49535298347473],
#               'E_fp': [1.2752532064914703],
#               'E_fn': [0.38637712597846985]}),
#  defaultdict(list,
#              {'seed_eta': [-2.5866570472717285],
#               'seed_en': [29.37261962890625],
#               'seed_et': [4.396915611875935],
#               'ncls': [4],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.5918794314438216],
#               'Etrue': [49.62601852416992],
#               'Epred': [29.37261962890625],
#               'E_tp': [29.37261962890625],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [2.54426646232605],
#               'seed_en': [416.4759826660156],
#               'seed_et': [65.01131887084699],
#               'ncls': [2],
#               'ncls_sel': [1],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [1.0138264355963085],
#               'Etrue': [416.60076904296875],
#               'Epred': [422.3608727455139],
#               'E_tp': [416.4759826660156],
#               'E_fp': [5.884890079498291],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [1.4446251392364502],
#               'seed_en': [96.48179626464844],
#               'seed_et': [43.109789860848615],
#               'ncls': [7],
#               'ncls_sel': [1],
#               'ncls_true': [1],
#               'ncls_sel_true': [1],
#               'seed_sel': [1],
#               'EoEtrue': [1.0006153816087906],
#               'Etrue': [109.11482238769531],
#               'Epred': [109.18196964263916],
#               'E_tp': [109.18196964263916],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-1.5044240951538086],
#               'seed_en': [27.39256477355957],
#               'seed_et': [11.597913615305389],
#               'ncls': [2],
#               'ncls_sel': [2],
#               'ncls_true': [2],
#               'ncls_sel_true': [2],
#               'seed_sel': [1],
#               'EoEtrue': [0.7900188227647099],
#               'Etrue': [37.428245544433594],
#               'Epred': [29.569018483161926],
#               'E_tp': [29.569018483161926],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-1.385212779045105],
#               'seed_en': [14.186907768249512],
#               'seed_et': [6.682565403739125],
#               'ncls': [15],
#               'ncls_sel': [7],
#               'ncls_true': [2],
#               'ncls_sel_true': [2],
#               'seed_sel': [1],
#               'EoEtrue': [1.0773263524496879],
#               'Etrue': [23.67262840270996],
#               'Epred': [25.503146409988403],
#               'E_tp': [20.36633014678955],
#               'E_fp': [5.1368162631988525],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [0.22751502692699432],
#               'seed_en': [72.30487060546875],
#               'seed_et': [70.47303821848487],
#               'ncls': [4],
#               'ncls_sel': [1],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [1.0083339628339911],
#               'Etrue': [72.34610748291016],
#               'Epred': [72.94903725385666],
#               'E_tp': [72.30487060546875],
#               'E_fp': [0.6441666483879089],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [2.64571213722229],
#               'seed_en': [255.36891174316406],
#               'seed_et': [36.05776739911505],
#               'ncls': [0],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9638289792493956],
#               'Etrue': [264.9525146484375],
#               'Epred': [255.36891174316406],
#               'E_tp': [255.36891174316406],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-0.0780627578496933],
#               'seed_en': [36.7313346862793],
#               'seed_et': [36.61970155264821],
#               'ncls': [6],
#               'ncls_sel': [1],
#               'ncls_true': [1],
#               'ncls_sel_true': [1],
#               'seed_sel': [1],
#               'EoEtrue': [0.9613306191167199],
#               'Etrue': [38.91147994995117],
#               'Epred': [37.40679711103439],
#               'E_tp': [37.40679711103439],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-2.2057552337646484],
#               'seed_en': [18.519853591918945],
#               'seed_et': [4.031632977346797],
#               'ncls': [8],
#               'ncls_sel': [3],
#               'ncls_true': [2],
#               'ncls_sel_true': [2],
#               'seed_sel': [1],
#               'EoEtrue': [1.0578265802304343],
#               'Etrue': [34.15400314331055],
#               'Epred': [36.1290123462677],
#               'E_tp': [33.618545055389404],
#               'E_fp': [2.510467290878296],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [1.4711039066314697],
#               'seed_en': [171.6370391845703],
#               'seed_et': [74.88999569395826],
#               'ncls': [15],
#               'ncls_sel': [2],
#               'ncls_true': [4],
#               'ncls_sel_true': [2],
#               'seed_sel': [1],
#               'EoEtrue': [0.9499853817067032],
#               'Etrue': [188.1590118408203],
#               'Epred': [178.74831068515778],
#               'E_tp': [178.74831068515778],
#               'E_fp': [0.0],
#               'E_fn': [2.497413694858551]}),
#  defaultdict(list,
#              {'seed_eta': [1.7076441049575806],
#               'seed_en': [180.54312133789062],
#               'seed_et': [63.37911296641988],
#               'ncls': [7],
#               'ncls_sel': [3],
#               'ncls_true': [2],
#               'ncls_sel_true': [1],
#               'seed_sel': [1],
#               'EoEtrue': [0.9793236281222388],
#               'Etrue': [192.74293518066406],
#               'Epred': [188.75771057605743],
#               'E_tp': [187.50247144699097],
#               'E_fp': [1.2552391290664673],
#               'E_fn': [0.6854845285415649]}),
#  defaultdict(list,
#              {'seed_eta': [-1.4100481271743774],
#               'seed_en': [7.220970153808594],
#               'seed_et': [3.327418223725398],
#               'ncls': [13],
#               'ncls_sel': [6],
#               'ncls_true': [4],
#               'ncls_sel_true': [4],
#               'seed_sel': [1],
#               'EoEtrue': [0.8917436805861223],
#               'Etrue': [24.3358154296875],
#               'Epred': [21.701309621334076],
#               'E_tp': [20.970789313316345],
#               'E_fp': [0.7305203080177307],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-2.578261613845825],
#               'seed_en': [378.25579833984375],
#               'seed_et': [57.09468823808572],
#               'ncls': [1],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [1.0109547202341331],
#               'Etrue': [374.1570129394531],
#               'Epred': [378.25579833984375],
#               'E_tp': [378.25579833984375],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [1.6870977878570557],
#               'seed_en': [152.35032653808594],
#               'seed_et': [54.51956979226128],
#               'ncls': [9],
#               'ncls_sel': [3],
#               'ncls_true': [4],
#               'ncls_sel_true': [3],
#               'seed_sel': [1],
#               'EoEtrue': [0.9116620376501999],
#               'Etrue': [174.48565673828125],
#               'Epred': [159.07194936275482],
#               'E_tp': [159.07194936275482],
#               'E_fp': [0.0],
#               'E_fn': [3.0611679553985596]}),
#  defaultdict(list,
#              {'seed_eta': [-0.17140164971351624],
#               'seed_en': [52.50063705444336],
#               'seed_et': [51.73877019036076],
#               'ncls': [6],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9667852827957487],
#               'Etrue': [54.30434036254883],
#               'Epred': [52.50063705444336],
#               'E_tp': [52.50063705444336],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [1.4732604026794434],
#               'seed_en': [43.7199821472168],
#               'seed_et': [19.039251695785655],
#               'ncls': [10],
#               'ncls_sel': [3],
#               'ncls_true': [3],
#               'ncls_sel_true': [3],
#               'seed_sel': [1],
#               'EoEtrue': [0.8871181681488359],
#               'Etrue': [59.78936767578125],
#               'Epred': [53.040234327316284],
#               'E_tp': [53.040234327316284],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-1.5672309398651123],
#               'seed_en': [150.78091430664062],
#               'seed_et': [60.28850621879128],
#               'ncls': [6],
#               'ncls_sel': [3],
#               'ncls_true': [2],
#               'ncls_sel_true': [1],
#               'seed_sel': [1],
#               'EoEtrue': [0.9700500556807409],
#               'Etrue': [174.46458435058594],
#               'Epred': [169.2393797636032],
#               'E_tp': [166.53422927856445],
#               'E_fp': [2.7051504850387573],
#               'E_fn': [5.722475528717041]}),
#  defaultdict(list,
#              {'seed_eta': [0.4371829628944397],
#               'seed_en': [51.36442184448242],
#               'seed_et': [46.81851721080656],
#               'ncls': [14],
#               'ncls_sel': [1],
#               'ncls_true': [1],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9710061017672793],
#               'Etrue': [53.21125793457031],
#               'Epred': [51.66845613718033],
#               'E_tp': [51.36442184448242],
#               'E_fp': [0.3040342926979065],
# ...
#               'E_tp': [276.2463073730469],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [0.010996001772582531],
#               'seed_en': [67.13780975341797],
#               'seed_et': [67.13375107262249],
#               'ncls': [3],
#               'ncls_sel': [2],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9890770501803493],
#               'Etrue': [68.61618041992188],
#               'Epred': [67.86668932437897],
#               'E_tp': [67.13780975341797],
#               'E_fp': [0.7288795709609985],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-0.663004457950592],
#               'seed_en': [22.63875961303711],
#               'seed_et': [18.436110921198438],
#               'ncls': [10],
#               'ncls_sel': [2],
#               'ncls_true': [1],
#               'ncls_sel_true': [1],
#               'seed_sel': [1],
#               'EoEtrue': [0.9761536643245711],
#               'Etrue': [38.42990493774414],
#               'Epred': [37.51349252462387],
#               'E_tp': [37.2309455871582],
#               'E_fp': [0.2825469374656677],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [1.9337983131408691],
#               'seed_en': [27.144847869873047],
#               'seed_et': [7.689403054678772],
#               'ncls': [9],
#               'ncls_sel': [3],
#               'ncls_true': [3],
#               'ncls_sel_true': [2],
#               'seed_sel': [1],
#               'EoEtrue': [0.8027529192186444],
#               'Etrue': [39.70127487182617],
#               'Epred': [31.870314300060272],
#               'E_tp': [30.91319990158081],
#               'E_fp': [0.9571143984794617],
#               'E_fn': [3.21492338180542]}),
#  defaultdict(list,
#              {'seed_eta': [1.3523989915847778],
#               'seed_en': [118.32210540771484],
#               'seed_et': [57.36398724293986],
#               'ncls': [14],
#               'ncls_sel': [5],
#               'ncls_true': [3],
#               'ncls_sel_true': [3],
#               'seed_sel': [1],
#               'EoEtrue': [0.9809361865660696],
#               'Etrue': [143.77354431152344],
#               'Epred': [141.03267228603363],
#               'E_tp': [139.23392033576965],
#               'E_fp': [1.798751950263977],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-1.9138720035552979],
#               'seed_en': [136.81138610839844],
#               'seed_et': [39.50207110288087],
#               'ncls': [2],
#               'ncls_sel': [2],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [1.030694082057398],
#               'Etrue': [134.7300262451172],
#               'Epred': [138.8654407262802],
#               'E_tp': [136.81138610839844],
#               'E_fp': [2.054054617881775],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [2.890216112136841],
#               'seed_en': [315.769775390625],
#               'seed_et': [34.98298614250797],
#               'ncls': [1],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9809216382784481],
#               'Etrue': [321.91131591796875],
#               'Epred': [315.769775390625],
#               'E_tp': [315.769775390625],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-0.8318326473236084],
#               'seed_en': [17.618988037109375],
#               'seed_et': [12.894570135161631],
#               'ncls': [10],
#               'ncls_sel': [2],
#               'ncls_true': [1],
#               'ncls_sel_true': [1],
#               'seed_sel': [1],
#               'EoEtrue': [0.9286550402363892],
#               'Etrue': [21.299373626708984],
#               'Epred': [19.77977067232132],
#               'E_tp': [19.158692359924316],
#               'E_fp': [0.6210783123970032],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-1.8039203882217407],
#               'seed_en': [247.94747924804688],
#               'seed_et': [79.49502118303445],
#               'ncls': [7],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.99469860903068],
#               'Etrue': [249.26895141601562],
#               'Epred': [247.94747924804688],
#               'E_tp': [247.94747924804688],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-0.03895893320441246],
#               'seed_en': [66.61417388916016],
#               'seed_et': [66.56365239442962],
#               'ncls': [7],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.992668721222565],
#               'Etrue': [67.10614776611328],
#               'Epred': [66.61417388916016],
#               'E_tp': [66.61417388916016],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [1.7696644067764282],
#               'seed_en': [126.61433410644531],
#               'seed_et': [41.93031870132576],
#               'ncls': [5],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9880005834323085],
#               'Etrue': [128.15208435058594],
#               'Epred': [126.61433410644531],
#               'E_tp': [126.61433410644531],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [1.3970825672149658],
#               'seed_en': [44.82619857788086],
#               'seed_et': [20.894566412614015],
#               'ncls': [12],
#               'ncls_sel': [4],
#               'ncls_true': [4],
#               'ncls_sel_true': [3],
#               'seed_sel': [1],
#               'EoEtrue': [0.9329983965108085],
#               'Etrue': [63.15584945678711],
#               'Epred': [58.92430627346039],
#               'E_tp': [58.22408628463745],
#               'E_fp': [0.700219988822937],
#               'E_fn': [0.6903653740882874]}),
#  defaultdict(list,
#              {'seed_eta': [0.4990505874156952],
#               'seed_en': [87.82083892822266],
#               'seed_et': [77.91532781576217],
#               'ncls': [8],
#               'ncls_sel': [2],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [1.0142931246685079],
#               'Etrue': [87.91845703125],
#               'Epred': [89.1750864982605],
#               'E_tp': [87.82083892822266],
#               'E_fp': [1.3542475700378418],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-0.6512782573699951],
#               'seed_en': [77.20481872558594],
#               'seed_et': [63.29898596275028],
#               'ncls': [16],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9938269998413906],
#               'Etrue': [77.68436431884766],
#               'Epred': [77.20481872558594],
#               'E_tp': [77.20481872558594],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [2.491450309753418],
#               'seed_en': [336.447998046875],
#               'seed_et': [55.32969257617894],
#               'ncls': [4],
#               'ncls_sel': [1],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9853983521579383],
#               'Etrue': [344.67889404296875],
#               'Epred': [339.646014213562],
#               'E_tp': [336.447998046875],
#               'E_fp': [3.1980161666870117],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-1.7941111326217651],
#               'seed_en': [127.83599090576172],
#               'seed_et': [41.36818145895905],
#               'ncls': [14],
#               'ncls_sel': [3],
#               'ncls_true': [1],
#               'ncls_sel_true': [1],
#               'seed_sel': [1],
#               'EoEtrue': [0.9897949239161206],
#               'Etrue': [144.1844940185547],
#               'Epred': [142.71308028697968],
#               'E_tp': [140.48476886749268],
#               'E_fp': [2.2283114194869995],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [2.3670313358306885],
#               'seed_en': [335.69110107421875],
#               'seed_et': [62.39935683450535],
#               'ncls': [7],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [1.0302742505477116],
#               'Etrue': [325.8269348144531],
#               'Epred': [335.69110107421875],
#               'E_tp': [335.69110107421875],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-0.004371813498437405],
#               'seed_en': [16.405454635620117],
#               'seed_et': [16.405297860165298],
#               'ncls': [4],
#               'ncls_sel': [2],
#               'ncls_true': [1],
#               'ncls_sel_true': [1],
#               'seed_sel': [1],
#               'EoEtrue': [1.0307778920123425],
#               'Etrue': [19.79216957092285],
#               'Epred': [20.401330828666687],
#               'E_tp': [19.0656418800354],
#               'E_fp': [1.3356889486312866],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-0.49607810378074646],
#               'seed_en': [16.799427032470703],
#               'seed_et': [14.924984094851292],
#               'ncls': [10],
#               'ncls_sel': [2],
#               'ncls_true': [2],
#               'ncls_sel_true': [2],
#               'seed_sel': [1],
#               'EoEtrue': [0.9356962205396221],
#               'Etrue': [25.252460479736328],
#               'Epred': [23.628631830215454],
#               'E_tp': [23.628631830215454],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-2.712247610092163],
#               'seed_en': [93.42266845703125],
#               'seed_et': [12.34975200828236],
#               'ncls': [1],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9258795559986771],
#               'Etrue': [100.90153503417969],
#               'Epred': [93.42266845703125],
#               'E_tp': [93.42266845703125],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-2.610396146774292],
#               'seed_en': [418.1396789550781],
#               'seed_et': [61.14071850125071],
#               'ncls': [3],
#               'ncls_sel': [1],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [1.0488252752726919],
#               'Etrue': [410.91400146484375],
#               'Epred': [430.97699069976807],
#               'E_tp': [418.1396789550781],
#               'E_fp': [12.837311744689941],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-1.0767154693603516],
#               'seed_en': [85.11967468261719],
#               'seed_et': [51.96979666379577],
#               'ncls': [14],
#               'ncls_sel': [6],
#               'ncls_true': [5],
#               'ncls_sel_true': [5],
#               'seed_sel': [1],
#               'EoEtrue': [0.9614589018167142],
#               'Etrue': [110.50335693359375],
#               'Epred': [106.24443620443344],
#               'E_tp': [105.79153406620026],
#               'E_fp': [0.4529021382331848],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [2.33024001121521],
#               'seed_en': [239.24551391601562],
#               'seed_et': [46.107702251743966],
#               'ncls': [6],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [1.0071788952799359],
#               'Etrue': [237.5402374267578],
#               'Epred': [239.24551391601562],
#               'E_tp': [239.24551391601562],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [0.27337950468063354],
#               'seed_en': [19.496051788330078],
#               'seed_et': [18.789537239619467],
#               'ncls': [9],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9437002670397073],
#               'Etrue': [20.659156799316406],
#               'Epred': [19.496051788330078],
#               'E_tp': [19.496051788330078],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [-2.2194836139678955],
#               'seed_en': [338.9857482910156],
#               'seed_et': [72.81213837771061],
#               'ncls': [9],
#               'ncls_sel': [2],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [1.0038752238264481],
#               'Etrue': [343.3674011230469],
#               'Epred': [344.6980266571045],
#               'E_tp': [338.9857482910156],
#               'E_fp': [5.712278366088867],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [1.9376519918441772],
#               'seed_en': [168.97979736328125],
#               'seed_et': [47.69080600769424],
#               'ncls': [8],
#               'ncls_sel': [2],
#               'ncls_true': [1],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [0.9776210719917712],
#               'Etrue': [175.891845703125],
#               'Epred': [171.95557475090027],
#               'E_tp': [168.97979736328125],
#               'E_fp': [2.9757773876190186],
#               'E_fn': [2.63612961769104]}),
#  defaultdict(list,
#              {'seed_eta': [-0.832892119884491],
#               'seed_en': [24.988407135009766],
#               'seed_et': [18.274722705742388],
#               'ncls': [7],
#               'ncls_sel': [2],
#               'ncls_true': [1],
#               'ncls_sel_true': [1],
#               'seed_sel': [1],
#               'EoEtrue': [0.21948794245765121],
#               'Etrue': [133.49032592773438],
#               'Epred': [29.29951697587967],
#               'E_tp': [28.728070735931396],
#               'E_fp': [0.5714462399482727],
#               'E_fn': [0.0]}),
#  defaultdict(list,
#              {'seed_eta': [1.025542140007019],
#               'seed_en': [9.684152603149414],
#               'seed_et': [6.154121327368619],
#               'ncls': [16],
#               'ncls_sel': [4],
#               'ncls_true': [3],
#               'ncls_sel_true': [2],
#               'seed_sel': [1],
#               'EoEtrue': [0.9937660033900997],
#               'Etrue': [12.52624225616455],
#               'Epred': [12.448153704404831],
#               'E_tp': [11.67564281821251],
#               'E_fp': [0.7725108861923218],
#               'E_fn': [0.40341269969940186]}),
#  defaultdict(list,
#              {'seed_eta': [-2.385542154312134],
#               'seed_en': [474.2699279785156],
#               'seed_et': [86.56937741831312],
#               'ncls': [3],
#               'ncls_sel': [0],
#               'ncls_true': [0],
#               'ncls_sel_true': [0],
#               'seed_sel': [1],
#               'EoEtrue': [1.0189082037806312],
#               'Etrue': [465.46875],
#               'Epred': [474.2699279785156],
#               'E_tp': [474.2699279785156],
#               'E_fp': [0.0],
#               'E_fn': [0.0]}),
#  ...]

# %%
data_final_calo = {}

for k in data_calos[0].keys():
    data_final_calo[k] = np.concatenate([l[k] for l in data_calos])

# %%
dfc = pd.DataFrame(data_final_calo)

# %%
dfc
# Out:
#         seed_eta     seed_en    seed_et  ncls  ncls_sel  ncls_true  \
# 0      -1.567780  214.772797  85.831885     2         1          1
# 1       0.975622   51.865986  34.237520     7         1          2
# 2      -0.678255   20.753859  16.750907     6         3          2
# 3      -2.761141  430.255737  54.184609     0         0          0
# 4      -0.724205   60.287922  47.325473     3         0          0
# ...          ...         ...        ...   ...       ...        ...
# 784626 -1.003359   26.743229  17.286742     7         1          1
# 784627 -2.226459  276.047913  58.890813     3         0          0
# 784628  1.004301   68.684143  44.365311     3         1          0
# 784629 -0.520376   26.544329  23.315611    13         2          2
# 784630  1.877269   20.272398   6.061742     9         1          1
#
#         ncls_sel_true  seed_sel   EoEtrue       Etrue       Epred        E_tp  \
# 0                   1         1  0.995310  218.356216  217.332209  217.332209
# 1                   1         1  0.938161   62.820969   58.936201   58.936201
# 2                   2         1  0.950007   34.942646   33.195758   32.724993
# 3                   0         1  0.987182  435.842346  430.255737  430.255737
# 4                   0         1  0.970471   62.122326   60.287922   60.287922
# ...               ...       ...       ...         ...         ...         ...
# 784626              1         1  0.956241   40.824005   39.037586   39.037586
# 784627              0         1  0.971173  284.241730  276.047913  276.047913
# 784628              0         1  0.997744   69.125084   68.969165   68.684143
# 784629              2         1  0.961431   47.763058   45.920883   45.920883
# 784630              1         1  0.896484   39.691193   35.582503   35.582503
#
#             E_fp      E_fn
# 0       0.000000  0.000000
# 1       0.000000  0.799801
# 2       0.470765  0.000000
# 3       0.000000  0.000000
# 4       0.000000  0.000000
# ...          ...       ...
# 784626  0.000000  0.000000
# 784627  0.000000  0.000000
# 784628  0.285022  0.000000
# 784629  0.000000  0.000000
# 784630  0.000000  0.000000
#
# [784631 rows x 14 columns]

# %%
data_final_calo = {}
data_final_nocalo = {}

for k,v in data_calos.items():
    data_final_calo[k] = np.concatenate(v)
    
for k,v in data_nocalo.items():
    data_final_nocalo[k] = np.concatenate(v)
    
import pandas as pd
dfc = pd.DataFrame(data_final_calo)
dfnc = pd.DataFrame(data_final_nocalo)

# %%
dfc = pd.DataFrame(data_calo)

# %%
import pickle
pickle.dump(dfc, open("df_calomatched_match_mustach.pkl","wb"))

# %%
from collections import defaultdict
import matplotlib.colors as colors
import matplotlib.pyplot as plt

#mport mplhep as hep
#lt.style.use(hep.style.CMS)

import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (5,4)
mpl.rcParams['figure.dpi'] = 150
mpl.rcParams["image.origin"] = 'lower'

# %%
ets = [0,5,10,15, 20,40,60,80,100]
etas = [0, 0.4,0.8, 1.2,1.479, 1.75,2.,2.3,2.6,3]
ncls = [0,2,3,5,10,15,20,25,30,35,50]

dfc["eta_bin"] = pd.cut(abs(dfc.seed_eta), etas, labels=list(range(len(etas)-1)))
dfc["et_bin"] = pd.cut(dfc.seed_et, ets, labels=list(range(len(ets)-1)))
dfc["ncls_bin"] = pd.cut(dfc.ncls, ncls, labels=list(range(len(ncls)-1)))

# %%
fig, ax = plt.subplots(2,4, figsize=(20,10),dpi=200)

etas = [ (0,1),(1,1.479),(1.479,2), (2,3)]

for j,(e1,e2) in enumerate(etas): 
    ax[0,j].hist(dfc[(abs(dfc.seed_eta)>=e1) & (abs(dfc.seed_eta)<e2)].EoEtrue,bins=80, range=(0,1.5),histtype='step')
    ax[0,j].legend()
    ax[0,j].set_title('{} < Eta < {}'.format(e1,e2))   
    ax[1,j].hist(dfc[(abs(dfc.seed_eta)>=e1) & (abs(dfc.seed_eta)<e2)].EoEtrue,bins=80, range=(0,1.5),histtype='step')
    ax[1,j].legend()
    ax[1,j].set_xlabel("E/Etrue")
    ax[1,j].set_title('{} < Eta < {}'.format(e1,e2))  
    ax[1,j].set_yscale('log')
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
fig, ax = plt.subplots(2,4, figsize=(20,10),dpi=200)

ets = [ (0,5),(5,10),(10,40), (40,100)]

for j,(e1,e2) in enumerate(ets): 
    ax[0,j].hist(dfc[ (dfc.seed_et>=e1) & (dfc.seed_et<e2)].EoEtrue,bins=80, range=(0,1.5),histtype='step')
    ax[0,j].set_title('{} < Seed Et < {}'.format(e1,e2))   
    ax[1,j].hist(dfc[ (dfc.seed_et>=e1) & (dfc.seed_et<e2)].EoEtrue,bins=80, range=(0,1.5),histtype='step')
    ax[1,j].set_xlabel("E/Etrue")
    ax[1,j].set_title('{} < Seed Et < {}'.format(e1,e2))  
    ax[1,j].set_yscale('log')

# %%
fig, ax = plt.subplots(4,4, figsize=(20,20),dpi=200)

ets = [ (0,5),(5,10),(10,40), (40,100)]
etas = [ (0,1),(1,1.479),(1.479,2), (2,3)]

for i,(ea1,ea2) in enumerate(etas):
    for j,(et1,et2) in enumerate(ets): 
        ax[i,j].hist(dfc[ (dfc.seed_et>=et1) & (dfc.seed_et<et2) \
                    & (abs(dfc.seed_eta)>=ea1) & (abs(dfc.seed_eta)<ea2)].EoEtrue,bins=60, range=(0,1.5),histtype='step')
        ax[i,j].set_title('{} < Seed Et < {}, {} < Seed Eta < {},'.format(et1,et2,ea1,ea2))

# %%
fig, ax = plt.subplots(4,4, figsize=(20,20),dpi=200)

ets = [ (0,5),(5,10),(10,30), (30,100)]
etas = [ (0,1),(1,1.479),(1.479,2), (2,3)]

for i,(ea1,ea2) in enumerate(etas):
    for j,(et1,et2) in enumerate(ets): 
        ax[i,j].hist(dfc[(dfc.seed_et>=et1) & (dfc.seed_et<et2) \
                             & (abs(dfc.seed_eta)>=ea1) & (abs(dfc.seed_eta)<ea2)].EoEtrue,bins=60, range=(0,1.5),histtype='step')
        ax[i,j].set_title('{} < Seed Et < {}, {} < Seed Eta < {},'.format(et1,et2,ea1,ea2))  
        ax[i,j].set_yscale('log')

# %%
plt.hist(dfc.EoEtrue,bins=80, range=(0,2),histtype='step')

plt.xlabel("E predicted / E true")
plt.yscale("log")

# %%
plt.hist(dfc.EoEtrue,bins=80, range=(0,2),histtype='step')

plt.xlabel("E predicted / E true")
# Out:
# Text(0.5, 0, 'E predicted / E true')

# %%
plt.hist(dfc[ (dfc.seed_et>50)].EoEtrue,bins=80, range=(0,2),histtype='step',label='Seed Et>50')
plt.hist(dfc[ (dfc.seed_et<=50)].EoEtrue,bins=80, range=(0,2),histtype='step',label='Seed Et<50')
plt.xlabel("E predicted / E true")
plt.yscale("log")
plt.legend()
#hep.cms.text("Simulation")
#hep.mpl_magic()

# %%
plt.hist(dfc.ncls, range=(0,30), bins=30)
plt.xlabel("N. clusters")
# Out:
# Text(0.5, 0, 'N. clusters')

# %%
fig, ax = plt.subplots(2,5, figsize=(25,10),dpi=300)

etas = [ (0,0.5),(0.5,1),(1,1.479),(1.479,2), (2,3)]

for j,(e1,e2) in enumerate(etas): 
    ax[0,j].hist(dfc[(abs(dfc.seed_eta)>=e1) & (abs(dfc.seed_eta)<e2)].ncls_sel,bins=10, range=(0,10),histtype='step', label="Mustache")
    ax[0,j].set_title('{} < Eta < {}'.format(e1,e2))   
    ax[1,j].hist(dfc[ (abs(dfc.seed_eta)>=e1) & (abs(dfc.seed_eta)<e2)].ncls_sel,bins=10, range=(0,10),histtype='step', label="Mustache")

    ax[1,j].set_xlabel("N. clusters selected")
    ax[1,j].set_title('{} < Eta < {}'.format(e1,e2))  
    ax[1,j].set_yscale('log')
    ax[0,j].hist(dfc[(abs(dfc.seed_eta)>=e1) & (abs(dfc.seed_eta)<e2)].ncls_true,bins=10, range=(0,10),histtype='step', label='True', linewidth=3,linestyle=':')
    ax[1,j].hist(dfc[(abs(dfc.seed_eta)>=e1) & (abs(dfc.seed_eta)<e2)].ncls_true,bins=10, range=(0,10),histtype='step', label='True', linewidth=3,linestyle=':')
    ax[0,j].legend()
    ax[1,j].legend()

# %%
ets = [0,5,10,15, 20,40,60,80,100]
etas = [0, 0.4,0.8, 1.2,1.479, 1.75,2.,2.3,2.6,3]
ncls = [0,2,3,5,10,15,20,25,30,35,50]

def plot_eteta2D(data, title, zlabel="",**kwargs):

    a = data.values.reshape((len(etas)-1,len(ets)-1))

    plt.figure(figsize=(10,5))
    plt.imshow(a.T,**kwargs)
    plt.xlabel("Seed $\eta$")
    plt.ylabel("Seed $E_T$")
    plt.title(title)
    plt.colorbar(label=zlabel)

    plt.yticks(np.arange(len(ets)-1), ets)
    plt.xticks(np.arange(len(etas)-1), etas)

    locs, labels= plt.xticks()
    labels.append(etas[-1])
    locs = np.append(locs, [len(etas)-1])
    plt.xticks(locs-0.5, labels)

    locs, labels= plt.yticks()
    labels.append(ets[-1])
    locs = np.append(locs, [len(ets)-1])
    plt.yticks(locs-0.5, labels)

def plot_nclseta2D(data, title, zlabel="", **kwargs):

    a = data.values.reshape((len(etas)-1,len(ncls)-1))

    plt.figure(figsize=(10,5))
    plt.imshow(a.T, **kwargs)
    plt.xlabel("Seed $\eta$")
    plt.ylabel("N. clusters")
    plt.title(title)
    plt.colorbar(label=zlabel)

    plt.yticks(np.arange(len(ncls)-1), ncls)
    plt.xticks(np.arange(len(etas)-1), etas)

    locs, labels= plt.xticks()
    labels.append(etas[-1])
    locs = np.append(locs, [len(etas)-1])
    plt.xticks(locs-0.5, labels)

    locs, labels= plt.yticks()
    labels.append(ncls[-1])
    locs = np.append(locs, [len(ncls)-1])
    plt.yticks(locs-0.5, labels)

# %% [markdown]
# # Resolution plots

# %%
result =  dfc[ (dfc.Etrue>1)].groupby(["eta_bin", "et_bin"]).EoEtrue.mean()

plot_eteta2D(result,"E/Etrue scale", vmin=0.5, vmax=1.2)

# %%
result =  dfc[(dfc.Etrue>5)].groupby(["eta_bin", "et_bin"]).EoEtrue.std()

plot_eteta2D(result,"E/Etrue Std.", vmin=0, vmax=0.5)

# %%
result =  dfc[ (dfc.Etrue>4)].groupby(["eta_bin", "ncls_bin"]).EoEtrue.count()

plot_nclseta2D(result,"N. windows", norm=colors.LogNorm())

# %%
result =  dfc[(dfc.Etrue>4)].groupby(["eta_bin", "ncls_bin"]).EoEtrue.mean()

plot_nclseta2D(result,"E/Etrue scale", vmin=0.86, vmax=1.025)

# %%
result =  dfc[ (dfc.Etrue>4)].groupby(["eta_bin", "ncls_bin"]).EoEtrue.std()

plot_nclseta2D(result,"E/Etrue std", vmin=0.02, vmax=0.23)

# %% [markdown]
# # Classification metric

# %%
result =  dfc[(dfc.Etrue>4)].groupby(["eta_bin", "et_bin"]).apply( lambda gr:  (gr.E_tp / gr.Etrue).mean())
plot_eteta2D(result,"Energy recall",vmin=0.5, vmax=1)

# %%
result =  dfc[(dfc.Etrue>4)].groupby(["eta_bin", "ncls_bin"]).apply( lambda gr:  (gr.E_tp / gr.Etrue).mean()).unstack(fill_value=0).stack()
plot_nclseta2D(result,"Energy recall", vmin=0.8, vmax=1)

# %%
result =  dfc[(dfc.Etrue>4)].groupby(["eta_bin", "et_bin"]).apply( lambda gr:  (gr.E_tp / gr.Epred).mean())
plot_eteta2D(result,"Energy precision", vmin=0.92, vmax=1)

# %%
result =  dfc[(dfc.Etrue>4)].groupby(["eta_bin", "ncls_bin"])\
       .apply(lambda gr:  (gr.E_tp / gr.Epred).mean())\
       .unstack(fill_value=0).stack()
plot_nclseta2D(result,"Energy precision", vmin=0.94, vmax=1)

# %%
result =  dfc[(dfc.Etrue>4)].groupby(["eta_bin", "et_bin"]).apply( lambda gr:  (gr.E_fp / gr.Epred).mean())

plot_eteta2D(result,"Energy contamination", vmin=0, vmax=0.06)

# %%
result =  dfc[(dfc.Etrue>4)].groupby(["eta_bin", "ncls_bin"])\
       .apply(lambda gr:  (gr.E_fp / gr.Epred).mean())\
       .unstack(fill_value=0).stack()
plot_nclseta2D(result,"Energy contamination", vmin=0, vmax=0.06)

# %%
result =  dfc[(dfc.thres==0.8)&(dfc.Etrue>4)].groupby(["eta_bin", "et_bin"]).apply( lambda gr:  (gr.E_fn / gr.Etrue).mean())

plot_eteta2D(result,"Energy miss rate", vmin=0, vmax=0.11)

# %%
result =  dfc[(dfc.Etrue>4) ].groupby(["eta_bin", "et_bin"]).ncls_true.mean()

plot_eteta2D(result,"Mean N. clusters selected", vmin=0, vmax=4)

# %%
result =  dfc[(dfc.Etrue>4)].groupby(["eta_bin", "ncls_bin"]).ncls_sel.mean()

plot_nclseta2D(result,"Mean N. clusters selected", vmin=0, vmax=12)

# %%
result =  dfc[(dfc.Etrue>4)].groupby(["eta_bin", "ncls_bin"]).ncls_sel.std()

plot_nclseta2D(result,"Std. N. clusters selected", vmin=0, vmax=4)

# %%
result =  dfc[(dfc.Etrue>4) & (dfc.ncls_true >0)].groupby(["eta_bin", "et_bin"]).apply( lambda gr:  (gr.ncls_sel_true / gr.ncls_true).mean())

plot_eteta2D(result,"N. clusters recall", vmin=0, vmax=1)

# %%
result =  dfc[(dfc.Etrue>4) & (dfc.ncls_true >0)].groupby(["eta_bin", "ncls_bin"])\
             .apply( lambda gr:  (gr.ncls_sel_true / gr.ncls_true).mean())\
             .unstack(fill_value=0).stack()

plot_nclseta2D(result,"N. clusters recall", vmin=0, vmax=1)

# %%
result =  dfc[(dfc.Etrue>4) & (dfc.ncls_true >0)].groupby(["eta_bin", "et_bin"])\
            .apply( lambda gr:  (gr.ncls_sel_true / gr.ncls_sel).mean())
plot_eteta2D(result,"N. clusters precision", vmin=0.5, vmax=1)

# %%
result =  dfc[(dfc.Etrue>4) & (dfc.ncls_true >0)].groupby(["eta_bin", "ncls_bin"])\
             .apply( lambda gr:  (gr.ncls_sel_true / gr.ncls_sel).mean())\
             .unstack(fill_value=0).stack()

plot_nclseta2D(result,"N. clusters precision",vmin=0.5, vmax=1)

# %%
result =  dfc[(dfc.Etrue>4) & (dfc.ncls_true >0)].groupby(["eta_bin", "ncls_bin"])\
        .apply( lambda gr:  (( gr.ncls_sel - gr.ncls_sel_true)/gr.ncls) .mean())\
       .unstack(fill_value=0).stack()

plot_nclseta2D(result,"Mean N. clusters contamination", vmin=0,vmax=0.3)
